# %% [markdown]
# # KdV equation with adaptive sampling measure

# %%
import jax
import jax.numpy as jnp
import optax
from Data import *
from Plot import *
from NeuralNetwork import *
from InitialFit import *
from Solver import *
from Error import *
from JaxUtils import *

# %% [markdown]
# ### Setup

# %%
# Exact solution

def exactKdVTwoSol(x, t):
    '''
    Function taken from https://github.com/pehersto/ng/solvers/exactKdV.py
    Args:
        x: jnp.array, points in space
        t: jnp.array (or float), points in time
    '''

    k = jnp.asarray([1., jnp.sqrt(5.)])
    eta = jnp.asarray([0., 10.73])
    t = jnp.asarray(t) # in case t is a float

    etaMat1 = k[0] * x.reshape((-1, 1)) - k[0] ** 3 * t.reshape((1, -1)) + eta[0]
    etaMat2 = k[1] * x.reshape((-1, 1)) - k[1] ** 3 * t.reshape((1, -1)) + eta[1]
    c = ((k[0] - k[1]) / (k[0] + k[1]) )** 2

    f = 1. + jnp.exp(etaMat1) + jnp.exp(etaMat2) + jnp.multiply(jnp.exp(etaMat1), jnp.exp(etaMat2) * c)
    df = k[0] * jnp.exp(etaMat1) + k[1] * jnp.exp(etaMat2) + c * (k[0] + k[1]) * jnp.multiply(jnp.exp(etaMat1), jnp.exp(etaMat2))
    ddf = k[0] ** 2 * jnp.exp(etaMat1) + k[1] ** 2 * jnp.exp(etaMat2) + c * (k[0] + k[1]) ** 2 * jnp.multiply(jnp.exp(etaMat1), jnp.exp(etaMat2))

    y = 2 * jnp.divide(jnp.multiply(f, ddf) - df ** 2, f ** 2)

    y = jnp.nan_to_num(y, nan=0.0, posinf=0.0, neginf=0.0) # avoid numerical errors far outside of [-1, 2]
    
    return y

# %%
problem_data = ProblemData(name='kdv_adaptive', # problem name
                           d=1, # input dimension
                           domain=(-20, 40), # 1D: (lower, upper)
                           T=6, # final time
                           initial_fn=lambda x: exactKdVTwoSol(x, 0), # initial condition
                           N=2048, # number of spatial points
                           dt=0.001, # time step
                          )

training_data = TrainingData(m=5, # number of neurons per layer
                             batch_size=10000, # batch size
                             epochs=100000, # number of epochs
                             gamma=0.1, # learning rate
                             scheduler=optax.linear_schedule(init_value=0.1, end_value=0.01, 
                                                             transition_steps=1000, transition_begin=1000) # learning rate scheduler
                            )

# %%
plot_function(problem_data.initial_fn, problem_data, 'Exact initial condition')
# Out:
# An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.

# %%
print(problem_data)
# Out:
# Problem data:
#   name: kdv_adaptive, d: 1, domain: (-20, 40), T: 6, N: 2048, dt: 0.01

# %%
print(training_data)
# Out:
# Training data:
#   m: 5, batch size: 10000, epochs: 100000, gamma: 0.1

# %% [markdown]
# ### Initial fit

# %%
# Neural network

net = DeepNetKdV(training_data.m)
print(net)
# Out:
# DeepNetKdV(
#     # attributes
#     m = 5
# )

# %%
# Initial fit

initial_fit = False

if initial_fit:
    theta = init_neural_galerkin(net, problem_data, training_data) # train a NN to fit the initial condition
    jnp.save('./data/theta_init_' + problem_data.name +'.npy', theta)
else:
    theta = jnp.load('./data/theta_init_' + problem_data.name + '.npy', allow_pickle=True).item()

# %% [markdown]
# ### Time evolution

# %%
theta_flat, unravel = jax.flatten_util.ravel_pytree(theta) # flatten a pytree of arrays down to a 1D array
u_fn = unraveler(net.apply, unravel) # auxiliary function that allows to evaluate the NN starting from the flattened parameters

# Define gradients
U = jax.vmap(u_fn, (None, 0)) # jax.vmap(fun, in_axes)
U_dtheta = jax.vmap(jax.grad(u_fn), (None, 0))
U_dx = jax.vmap(gradsqz(u_fn, 1), (None, 0))
U_dddx = jax.vmap(gradsqz(gradsqz(gradsqz(u_fn, 1), 1), 1), (None, 0))

# Source term for the KdV equation
def rhs(theta_flat, x, t):
    u = U(theta_flat, x)
    u_x = U_dx(theta_flat, x)
    u_xxx = U_dddx(theta_flat, x)
    return - u_xxx - 6 * u * u_x

# %%
# TODO: is there a way to put these functions in a separate file?

@jax.jit
def M_fn(theta_flat, x):
    '''
    Assemble the M matrix (with boundary correction).
    '''
    u_dth = U_dtheta(theta_flat, x)
    M = jnp.mean(u_dth[:, :, jnp.newaxis] * u_dth[:, jnp.newaxis, :], axis=0)
    
    zeta = 10000
    x_lower, x_upper = jnp.array(problem_data.domain[0]).reshape(-1, 1), jnp.array(problem_data.domain[1]).reshape(-1, 1)
    u_dth_lower, u_dth_upper = U_dtheta(theta_flat, x_lower), U_dtheta(theta_flat, x_upper)
    # B_lower, B_upper = ...
    B = zeta * (u_dth_lower + u_dth_upper) * jnp.mean(u_dth)
    
    return M # + B


@jax.jit
def F_fn(theta_flat, x, t):
    '''
    Assemble the F matrix.
    '''
    u_dth = U_dtheta(theta_flat, x)
    f = rhs(theta_flat, x, t) # source term
    F = jnp.mean(u_dth[:, :] * f[:, jnp.newaxis], axis=0)
    return F


@jax.jit
def r_fn(theta_flat, delta_theta_flat, x, t):
    '''
    Compute the local-in-time residual (with boundary correction).
    '''
    # zeta = 10000
    # x_lower, x_upper = jnp.array(problem_data.domain[0]).reshape(-1, 1), jnp.array(problem_data.domain[1]).reshape(-1, 1)
    
    # return jnp.dot((U_dtheta(theta_flat, x) + zeta * (U_dtheta(theta_flat, x_lower) + U_dtheta(theta_flat, x_upper))), delta_theta_flat) - rhs(theta_flat, x, t)
    if len(x.shape) == 1:
        r = jnp.dot(U_dtheta(theta_flat, x.reshape(-1, 1)), delta_theta_flat) - rhs(theta_flat, x.reshape(-1, 1), t)
        return r.squeeze()
    return jnp.dot(U_dtheta(theta_flat, x), delta_theta_flat) - rhs(theta_flat, x, t)

# %%
# AR method for the initial sampling from u

from scipy.stats import norm, uniform

def initial_sampling(f, n, max_it=1000):

    x = []
    C = 29
    g = norm(loc=-5, scale=4.5)

    for i in range(n):
        it = 0
        while it < max_it:
            y = g.rvs() # sample from the Gaussian
            u = uniform.rvs() # sample from a uniform in [0, 1]
            if u <= f(y) / (C * g.pdf(y)):
                x.append(y)
                break
            it += 1
        if it >= max_it:
            raise Exception("AR did not converge.")

    return jnp.array(x)


def KdVWrapper(x):
        x = jnp.array([x])
        kdv = exactKdVTwoSol(x, 0)
        return kdv.squeeze()

# %%
n = 100
x_test = initial_sampling(KdVWrapper, n)

x_plot = jnp.linspace(problem_data.domain[0], problem_data.domain[1], n)
plt.scatter(x_test, jnp.zeros(n), c='green', marker='x')
plt.plot(x_plot, exactKdVTwoSol(x_plot, 0))
plt.xlim([-10, 10])
plt.ylim([-0.1, 2.7])
plt.show()

# %%
@jax.jit
def SVGD_kernel(theta, h):
    '''
    Function adapted from: https://github.com/dilinwang820/Stein-Variational-Gradient-Descent/blob/master/python/svgd.py
    '''
    # sq_dist = pdist(theta)
    # pairwise_dists = squareform(sq_dist) ** 2
    theta_norm_squared = jnp.sum(theta ** 2, axis=1, keepdims=True)
    pairwise_dists = theta_norm_squared + theta_norm_squared.T - 2 * jnp.dot(theta, theta.T)
    # if h < 0: # median trick
    #     h = jnp.median(pairwise_dists)  
    #     h = jnp.sqrt(0.5 * h / jnp.log(theta.shape[0] + 1))

    # compute the rbf kernel
    Kxy = jnp.exp(- pairwise_dists / h ** 2 / 2)

    dxkxy = - jnp.matmul(Kxy, theta)
    sumkxy = jnp.sum(Kxy, axis=1)
    # for i in range(theta.shape[1]):
    #     dxkxy = dxkxy.at[:, i].set(dxkxy[:, i] + jnp.multiply(theta[:, i], sumkxy))
    dxkxy += jnp.multiply(theta, jnp.expand_dims(sumkxy, axis=1)) # vectorized
    dxkxy /= (h ** 2)
    return (Kxy, dxkxy)


def SVGD_update(x0, lnprob, n_iter=1000, stepsize=1e-3, alpha=1.0, debug=False):
    '''
    Function adapted from: https://github.com/dilinwang820/Stein-Variational-Gradient-Descent/blob/master/python/svgd.py
    '''
    # check input
    if x0 is None or lnprob is None:
        raise ValueError('x0 or lnprob cannot be None!')
    
    theta = jnp.copy(x0) 

    for iter in range(n_iter):
        if debug and (iter + 1) % 1000 == 0:
            print('iter', str(iter + 1))
        
        lnpgrad = lnprob(theta.squeeze()).reshape(-1, 1) # lnpgrad: (n, d)
        # calculating the kernel matrix
        kxy, dxkxy = SVGD_kernel(theta, h=0.05) # kxy: (n, n), dxkxy: (n, d)
        grad_theta = alpha * (jnp.matmul(kxy, lnpgrad) + dxkxy) / x0.shape[0] # grad_theta: (n, d)
        
        # vanilla update
        theta = theta + stepsize * grad_theta
        
    return theta

# %%
# Test SVGD against a simple Gaussian

@jax.jit
def gaussian(x, mu, sigma):
    return jnp.exp(- 0.5 * (x - mu) ** 2 / sigma ** 2)

@jax.jit
def log_gaussian(x, mu, sigma):
    return jnp.log(gaussian(x, mu, sigma))

@jax.jit
def log_gaussian_dx(x, mu, sigma):
    return jax.vmap(jax.grad(log_gaussian), (0, None, None))(x, mu, sigma)

def test_SVGD():
    
	# Initial particles
    x0 = jax.random.uniform(jax.random.key(0), shape=(20, ), minval=-10, maxval=10).reshape(-1, 1)
    
    dlnprob = lambda x: log_gaussian_dx(x, 0, 1)

    theta = SVGD_update(x0, dlnprob, n_iter=10000, stepsize=0.05, debug=True)

    print(theta)

    # Plot
    plt.scatter(x0, jnp.zeros_like(x0), color='blue', label='Initial particles')
    plt.scatter(theta, jnp.zeros_like(theta), color='red', label='Final particles')
    x_plot = jnp.linspace(-10, 10, 100)
    plt.plot(x_plot, gaussian(x_plot, 0, 1), color='black', label='Target distribution')
    plt.legend()
    plt.show()


test_SVGD()
# Out:
# An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.
# iter 1000
# iter 2000
# iter 3000
# iter 4000
# iter 5000
# iter 6000
# iter 7000
# iter 8000
# iter 9000
# iter 10000
# [[ 0.45057178]
#  [-0.7877321 ]
#  [-0.5577346 ]
#  [ 0.04885156]
#  [ 0.9145206 ]
#  [-1.0552185 ]
#  [-0.6696212 ]
#  [-0.14687295]
#  [ 0.1468921 ]
#  [ 0.78775394]
#  [-0.914499  ]
#  [ 0.6696425 ]
#  [-0.2459925 ]
#  [-0.34694618]
#  [ 0.2460119 ]
#  [ 0.5577553 ]
#  [-0.04883256]
#  [ 0.346966  ]
#  [ 1.0552403 ]
#  [-0.45055145]]

# %%
# @jax.jit
def predictor_corrector(theta_flat, x, t, dt, M_fn, F_fn):
    '''
    Predictor-corrector scheme based on forward Euler.
    '''
    M = M_fn(theta_flat, x)
    F = F_fn(theta_flat, x, t)
    theta_flat_pred = theta_flat + dt * jnp.linalg.lstsq(M, F)[0]
    return theta_flat_pred


sigma = 0.05

@jax.jit
def gaussian_kernel(x1, x2):
    # return jnp.exp(- jnp.abs(x1 - x2) ** 2 / (2 * sigma ** 2))
    return jnp.exp(- jnp.abs(x1[:, jnp.newaxis] - x2) ** 2 / (2 * sigma ** 2))

@jax.jit
def gaussian_kernel_dx(x1, x2):
    # return - (x1 - x2) * gaussian_kernel(x1, x2) / sigma ** 2
    return - (x1[:, jnp.newaxis] - x2) * gaussian_kernel(x1, x2) / sigma ** 2


def adaptive_sampling(theta_flat, problem_data, n, x, t, M_fn, F_fn, r_fn):
    '''
    Adaptive sampling with SVGD.
    '''
    alpha = 0.01 # scaling parameter... WHICH VALUE?
    gamma = 0.25 # tempering parameter
    epsilon = 0.05 # step size
    steps = 100 # 500

    # Predictor-corrector scheme
    theta_flat_pred = predictor_corrector(theta_flat, x, t, problem_data.dt, M_fn, F_fn)

    # The target measure is proportional to the residual scaled by a tempering parameter
    mu = lambda y: jnp.abs(r_fn(theta_flat, theta_flat_pred - theta_flat, y, t)) ** (2 * gamma)
    log_mu = lambda y: jnp.log(mu(y)) # log(mu) = - V
    log_mu_dx = jax.vmap(jax.grad(log_mu), 0)

    # Gaussian kernel
    # sigma = 0.05 # bandwidth
    # gaussian_kernel = lambda x1, x2: jnp.exp(- jnp.abs(x1 - x2) ** 2 / (2 * sigma ** 2))
    # gaussian_kernel_dx = lambda x1, x2: - (x1 - x2) * kernel(x1, x2) / sigma ** 2

    # print('Running SVGD...')

    for s in range(steps):
        # if s % 10 == 0:
        #     print(f'  s = {s}/{steps}')
        # phi = lambda y: alpha * jnp.mean(gaussian_kernel(x, y) * log_mu_dx(x) + gaussian_kernel_dx(x, y))
        # x = x + epsilon * jnp.array([phi(x_i) for x_i in x]).reshape(-1, 1)
        phi = lambda y: alpha * jnp.mean(gaussian_kernel(x, y) * log_mu_dx(x) + gaussian_kernel_dx(x, y), axis=1)
        x = x + epsilon * phi(x)

    return x

# %%
v1 = jnp.array([1,2,3])
v2 = jnp.array([4,5,6])
v3 = v1[:, jnp.newaxis] + v2
print(v3)
v4 = jnp.array([-1,2,-3])
v5 = v3 * v4
print(v5)
print(jnp.mean(v5, axis=1))
# Out:
# [[5 6 7]
#  [6 7 8]
#  [7 8 9]]
# [[ -5  12 -21]
#  [ -6  14 -24]
#  [ -7  16 -27]]
# [-4.666667  -5.3333335 -6.       ]

# %%
def neural_galerkin(theta_flat, problem_data, n, sampler, scheme):

    x_plot = jnp.linspace(problem_data.domain[0], problem_data.domain[1], problem_data.N) # points for plotting and error evaluation

    solution = []

    print('Run time evolution...')

    # Initialize the particles by sampling from the initial condition
    if sampler == 'svgd':
        x = initial_sampling(KdVWrapper, n).reshape(-1, 1)
        # x = jax.random.uniform(jax.random.key(0), (n, problem_data.d), minval=problem_data.domain[0], maxval=problem_data.domain[1])

    t = 0
    while t < problem_data.T:

        if int(t / problem_data.dt) % 20 == 0:
            print(f'  t = {t:.2f}/{problem_data.T:.2f}')
            plt.scatter(x, jnp.zeros(n), c='green', marker='x')
            plt.plot(x_plot, exactKdVTwoSol(x_plot, t))
            plt.plot(x_plot, U(theta_flat, x_plot.reshape(-1, 1)))
            plt.xlim([-10, 10])
            plt.ylim([-0.1, 2.7])
            plt.show()

        # Save current solution
        u = U(theta_flat, x_plot.reshape(-1, 1))
        solution.append(u)

        # Sample points in the spatial domain
        if sampler == 'unif':
            seed = int(t * 1e6)
            x = jax.random.uniform(jax.random.key(seed), (n, problem_data.d), minval=problem_data.domain[0], maxval=problem_data.domain[1])
        elif sampler == 'svgd':
            x = adaptive_sampling(theta_flat, problem_data, n, x, t, M_fn, F_fn, r_fn)
        else:
            print('Sampling strategy not implement yet.')
            raise NotImplementedError

        if scheme == 'rk45':
            theta_flat = runge_kutta_scheme(theta_flat, x, t, problem_data.dt, M_fn, F_fn)
        else:
            print('ODE solver not implemented yet.')
            raise NotImplementedError

        t = t + problem_data.dt

    return solution

# %%
solution = neural_galerkin(theta_flat=theta_flat, # parameters
                           problem_data=problem_data, # problem data
                           n=100, # sample points
                           sampler='svgd', # sampling strategy
                           scheme='rk45' # ODE solver
                          )
# Out:
# Run time evolution...
#   t = 0.00/6.00
#   t = 0.02/6.00
#   t = 0.04/6.00
#   t = 0.06/6.00
#   t = 0.08/6.00
#   t = 0.10/6.00
#   t = 0.12/6.00
#   t = 0.14/6.00
#   t = 0.16/6.00
#   t = 0.18/6.00
#   t = 0.20/6.00
#   t = 0.22/6.00
#   t = 0.24/6.00
#   t = 0.26/6.00
#   t = 0.28/6.00
#   t = 0.30/6.00
#   t = 0.32/6.00
#   t = 0.34/6.00
#   t = 0.36/6.00
#   t = 0.38/6.00
#   t = 0.40/6.00
#   t = 0.42/6.00
#   t = 0.44/6.00
#   t = 0.46/6.00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 solution = neural_galerkin(theta_flat=theta_flat, # parameters
#       2                            problem_data=problem_data, # problem data
#       3                            n=100, # sample points
#       4                            sampler='svgd', # sampling strategy
#       5                            scheme='rk45' # ODE solver
#       6                           )
#
# Cell In[25], line 35, in neural_galerkin(theta_flat, problem_data, n, sampler, scheme)
#      33     x = jax.random.uniform(jax.random.key(seed), (n, problem_data.d), minval=problem_data.domain[0], maxval=problem_data.domain[1])
#      34 elif sampler == 'svgd':
# ---> 35     x = adaptive_sampling(theta_flat, problem_data, n, x, t, M_fn, F_fn, r_fn)
#      36 else:
#      37     print('Sampling strategy not implement yet.')
#
# Cell In[29], line 55, in adaptive_sampling(theta_flat, problem_data, n, x, t, M_fn, F_fn, r_fn)
#      49 for s in range(steps):
#      50     # if s % 10 == 0:
#      51     #     print(f'  s = {s}/{steps}')
#      52     # phi = lambda y: alpha * jnp.mean(gaussian_kernel(x, y) * log_mu_dx(x) + gaussian_kernel_dx(x, y))
#      53     # x = x + epsilon * jnp.array([phi(x_i) for x_i in x]).reshape(-1, 1)
#      54     phi = lambda y: alpha * jnp.mean(gaussian_kernel(x, y) * log_mu_dx(x) + gaussian_kernel_dx(x, y), axis=1)
# ---> 55     x = x + epsilon * phi(x)
#      57 return x
#
# Cell In[29], line 54, in adaptive_sampling.<locals>.<lambda>(y)
#      42 # Gaussian kernel
#      43 # sigma = 0.05 # bandwidth
#      44 # gaussian_kernel = lambda x1, x2: jnp.exp(- jnp.abs(x1 - x2) ** 2 / (2 * sigma ** 2))
#      45 # gaussian_kernel_dx = lambda x1, x2: - (x1 - x2) * kernel(x1, x2) / sigma ** 2
#      46
#      47 # print('Running SVGD...')
#      49 for s in range(steps):
#      50     # if s % 10 == 0:
#      51     #     print(f'  s = {s}/{steps}')
#      52     # phi = lambda y: alpha * jnp.mean(gaussian_kernel(x, y) * log_mu_dx(x) + gaussian_kernel_dx(x, y))
#      53     # x = x + epsilon * jnp.array([phi(x_i) for x_i in x]).reshape(-1, 1)
# ---> 54     phi = lambda y: alpha * jnp.mean(gaussian_kernel(x, y) * log_mu_dx(x) + gaussian_kernel_dx(x, y), axis=1)
#      55     x = x + epsilon * phi(x)
#      57 return x
#
#     [... skipping hidden 1 frame]
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/api.py:1262, in vmap.<locals>.vmap_f(*args, **kwargs)
#    1259 in_axes_flat = flatten_axes("vmap in_axes", in_tree, (in_axes, 0), kws=True)
#    1260 axis_size_ = (axis_size if axis_size is not None else
#    1261               _mapped_axis_size(fun, in_tree, args_flat, in_axes_flat, "vmap"))
# -> 1262 out_flat = batching.batch(
#    1263     flat_fun, axis_name, axis_size_, in_axes_flat,
#    1264     lambda: flatten_axes("vmap out_axes", out_tree(), out_axes),
#    1265     spmd_axis_name=spmd_axis_name
#    1266 ).call_wrapped(*args_flat)
#    1267 return tree_unflatten(out_tree(), out_flat)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/linear_util.py:191, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     188 gen = gen_static_args = out_store = None
#     190 try:
# --> 191   ans = self.f(*args, **dict(self.params, **kwargs))
#     192 except:
#     193   # Some transformations yield from inside context managers, so we have to
#     194   # interrupt them before reraising the exception. Otherwise they will only
#     195   # get garbage-collected at some later time, running their cleanup tasks
#     196   # only after this exception is handled, which can corrupt the global
#     197   # state.
#     198   while stack:
#
#     [... skipping hidden 1 frame]
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/api.py:663, in grad.<locals>.grad_f(*args, **kwargs)
#     660 @wraps(fun, docstr=docstr, argnums=argnums)
#     661 @api_boundary
#     662 def grad_f(*args, **kwargs):
# --> 663   _, g = value_and_grad_f(*args, **kwargs)
#     664   return g
#
#     [... skipping hidden 1 frame]
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/api.py:745, in value_and_grad.<locals>.value_and_grad_f(*args, **kwargs)
#     743 _check_scalar(ans)
#     744 tree_map(partial(_check_output_dtype_grad, holomorphic), ans)
# --> 745 g = vjp_py(lax_internal._one(ans))
#     746 g = g[0] if isinstance(argnums, int) else g
#     747 if not has_aux:
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/tree_util.py:357, in _HashableCallableShim.__call__(self, *args, **kw)
#     356 def __call__(self, *args, **kw):
# --> 357   return self.fun(*args, **kw)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/api.py:2154, in _vjp_pullback_wrapper(name, cotangent_dtypes, cotangent_shapes, io_tree, fun, *py_args_)
#    2149   if np.shape(arg) != ct_shape:
#    2150     raise ValueError(
#    2151         f"Shape of cotangent input to vjp pullback function {np.shape(arg)} "
#    2152         "must be the same as the shape of corresponding primal input "
#    2153         f"{ct_shape}.")
# -> 2154 ans = fun(*args)
#    2155 return tree_unflatten(out_tree, ans)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/tree_util.py:357, in _HashableCallableShim.__call__(self, *args, **kw)
#     356 def __call__(self, *args, **kw):
# --> 357   return self.fun(*args, **kw)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:149, in vjp.<locals>.unbound_vjp(pvals, jaxpr, consts, *cts)
#     147 cts = tuple(ct for ct, pval in zip(cts, pvals) if not pval.is_known())
#     148 dummy_args = [UndefinedPrimal(v.aval) for v in jaxpr.invars]
# --> 149 arg_cts = backward_pass(jaxpr, reduce_axes, True, consts, dummy_args, cts)
#     150 return map(instantiate_zeros, arg_cts)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:253, in backward_pass(jaxpr, reduce_axes, transform_stack, consts, primals_in, cotangents_in)
#     250   cts_out = get_primitive_transpose(eqn.primitive)(
#     251       params, call_jaxpr, invals, cts_in, cts_in_avals, reduce_axes)
#     252 elif eqn.primitive in reducing_transposes:
# --> 253   cts_out = reducing_transposes[eqn.primitive](
#     254       reduce_axes, cts_in, *invals, **eqn.params)
#     255 else:
#     256   cts_out = get_primitive_transpose(eqn.primitive)(
#     257       cts_in, *invals, **eqn.params)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/pjit.py:1919, in _pjit_transpose(reduce_axes, cts_in, jaxpr, in_shardings, out_shardings, resource_env, donated_invars, name, keep_unused, inline, *primals_in)
#    1916   transpose_in_shardings = (UNSPECIFIED,) * len(attrs_tracked) + transpose_in_shardings
#    1917   transpose_out_shardings = (UNSPECIFIED,) * len(attrs_tracked) + transpose_out_shardings
# -> 1919 nz_cts_out = pjit_p.bind(
#    1920     *primals_and_nz_cts_in,
#    1921     jaxpr=transpose_jaxpr,
#    1922     in_shardings=transpose_in_shardings,
#    1923     out_shardings=transpose_out_shardings,
#    1924     resource_env=resource_env,
#    1925     donated_invars=(False,) * len(primals_and_nz_cts_in),
#    1926     name=name,
#    1927     keep_unused=keep_unused,
#    1928     inline=inline)
#    1929 if attrs_tracked:
#    1930   final_states, nz_cts_out = split_list(nz_cts_out, [len(init_states)])
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/core.py:2743, in AxisPrimitive.bind(self, *args, **params)
#    2739 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2740                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2741 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2742              else axis_main.with_cur_sublevel())
# -> 2743 return self.bind_with_trace(top_trace, args, params)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/core.py:447, in Primitive.bind_with_trace(self, trace, args, params)
#     446 def bind_with_trace(self, trace, args, params):
# --> 447   out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     448   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/core.py:538, in Trace.full_raise(self, val)
#     537 def full_raise(self, val) -> TracerType:
# --> 538   if hasattr(val, "dimension_as_value"):  # Used for shape_poly._DimPolynomial
#     539     val = val.dimension_as_value()
#     540   if not isinstance(val, Tracer):
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/core.py:811, in Tracer.__getattr__(self, name)
#     808 assert not config.enable_checks.value or name != "aval"
#     810 try:
# --> 811   attr = getattr(self.aval, name)
#     812 except AttributeError as err:
#     813   raise AttributeError(
#     814       f"{self.__class__.__name__} has no attribute {name}"
#     815   ) from err
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/batching.py:333, in BatchTracer.aval(self)
#     331 @property
#     332 def aval(self):
# --> 333   aval = raise_to_shaped(core.get_aval(self.val))
#     334   if self.batch_dim is not_mapped:
#     335     return aval
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/core.py:1956, in raise_to_shaped(aval, weak_type)
#    1954 for typ in aval_type.__mro__:
#    1955   handler = raise_to_shaped_mappings.get(typ)
# -> 1956   if handler: return handler(aval, weak_type)
#    1957 raise TypeError(type(aval))
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/core.py:1963, in <lambda>(aval, weak_type)
#    1956     if handler: return handler(aval, weak_type)
#    1957   raise TypeError(type(aval))
#    1959 raise_to_shaped_mappings : dict[type, Callable] = {
#    1960   AbstractToken: lambda aval, _: aval,
#    1961   Bot: lambda aval, _: aval,
#    1962   UnshapedArray: lambda aval, _: aval,
# -> 1963   ShapedArray: lambda aval, weak_type: ShapedArray(
#    1964       aval.shape, aval.dtype, weak_type, aval.named_shape),
#    1965   DConcreteArray: lambda aval, weak_type: DShapedArray(
#    1966       aval.shape, aval.dtype, weak_type),
#    1967 }
#    1969 ### Operations on shapes and dimension sizes.
#    1971 class InconclusiveDimensionOperation(Exception):
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/core.py:1659, in ShapedArray.__init__(self, shape, dtype, weak_type, named_shape)
#    1657 self.dtype = _dtype_object(dtype)
#    1658 self.weak_type = weak_type
# -> 1659 self.named_shape = {} if named_shape is None else dict(named_shape)
#
# KeyboardInterrupt:

# %%
plot_solution(solution)

# %%
plot_animation(solution, problem_data)

# %% [markdown]
# ### Compute relative error

# %%
errors = compute_error(solution, exactKdVTwoSol, problem_data)

# %%
plot_error(errors, problem_data, 'Relative L2 error')
