# %% [markdown]
# # KdV equation with adaptive sampling measure

# %%
import jax
import jax.numpy as jnp
import optax
from Data import *
from Plot import *
from NeuralNetwork import *
from InitialFit import *
from Solver import *
from Error import *
from JaxUtils import *

# %% [markdown]
# ### Setup

# %%
# Exact solution

def exactKdVTwoSol(x, t):
    '''
    Function taken from https://github.com/pehersto/ng/solvers/exactKdV.py
    Args:
        x: jnp.array, points in space
        t: jnp.array (or float), points in time
    '''

    k = jnp.asarray([1., jnp.sqrt(5.)])
    eta = jnp.asarray([0., 10.73])
    t = jnp.asarray(t) # in case t is a float

    etaMat1 = k[0] * x.reshape((-1, 1)) - k[0] ** 3 * t.reshape((1, -1)) + eta[0]
    etaMat2 = k[1] * x.reshape((-1, 1)) - k[1] ** 3 * t.reshape((1, -1)) + eta[1]
    c = ((k[0] - k[1]) / (k[0] + k[1]) )** 2

    f = 1. + jnp.exp(etaMat1) + jnp.exp(etaMat2) + jnp.multiply(jnp.exp(etaMat1), jnp.exp(etaMat2) * c)
    df = k[0] * jnp.exp(etaMat1) + k[1] * jnp.exp(etaMat2) + c * (k[0] + k[1]) * jnp.multiply(jnp.exp(etaMat1), jnp.exp(etaMat2))
    ddf = k[0] ** 2 * jnp.exp(etaMat1) + k[1] ** 2 * jnp.exp(etaMat2) + c * (k[0] + k[1]) ** 2 * jnp.multiply(jnp.exp(etaMat1), jnp.exp(etaMat2))

    y = 2 * jnp.divide(jnp.multiply(f, ddf) - df ** 2, f ** 2)

    y = jnp.nan_to_num(y, nan=0.0, posinf=0.0, neginf=0.0) # avoid numerical errors far outside of [-1, 2]
    
    return y

# %%
problem_data = ProblemData(name='kdv_adaptive', # problem name
                           d=1, # input dimension
                           domain=(-20, 40), # 1D: (lower, upper)
                           T=6, # final time
                           initial_fn=lambda x: exactKdVTwoSol(x, 0), # initial condition
                           N=2048, # number of spatial points
                           dt=0.01, # time step (if needed)
                          )

training_data = TrainingData(m=5, # number of neurons per layer
                             batch_size=10000, # batch size
                             epochs=100000, # number of epochs
                             gamma=0.1, # learning rate
                             seed=0, # seed for reproducibility
                             scheduler=optax.piecewise_constant_schedule(init_value=0.1, boundaries_and_scales={1000: 0.1, 10000: 0.1}) # learning rate scheduler
                             # scheduler=optax.exponential_decay(init_value=0.1, transition_steps=1000, decay_rate=0.9) # learning rate scheduler
                             # scheduler=optax.linear_schedule(init_value=0.1, end_value=0.01, 
                             #                                 transition_steps=1000, transition_begin=1000) # learning rate scheduler
                            )

# %%
plot_function(problem_data.initial_fn, problem_data, 'Exact initial condition')
# Out:
# An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.

# %%
print(problem_data)
# Out:
# Problem data:
#   name: kdv_adaptive, d: 1, domain: (-20, 40), T: 6, N: 2048, dt: 0.001

# %%
print(training_data)
# Out:
# Training data:
#   m: 5, batch size: 10000, epochs: 100000, gamma: 0.1, seed: 0, scheduler: <function piecewise_constant_schedule.<locals>.schedule at 0x7f59d2061ea0>

# %% [markdown]
# ### Initial fit

# %%
# Neural network

net = DeepNetKdV(training_data.m)
print(net)
# Out:
# DeepNetKdV(
#     # attributes
#     m = 5
# )

# %%
# Initial fit

initial_fit = False

if initial_fit:
    theta = init_neural_galerkin(net, problem_data, training_data) # train a NN to fit the initial condition
    jnp.save('./data/theta_init_' + problem_data.name + '_' + str(training_data.seed) + '.npy', theta)
else:
    theta = jnp.load('./data/theta_init_' + problem_data.name + '_' + str(training_data.seed) + '.npy', allow_pickle=True).item()

# %% [markdown]
# ### Time evolution

# %%
theta_flat, unravel = jax.flatten_util.ravel_pytree(theta) # flatten a pytree of arrays down to a 1D array
u_fn = unraveler(net.apply, unravel) # auxiliary function that allows to evaluate the NN starting from the flattened parameters

# Define gradients
U = jax.vmap(u_fn, (None, 0)) # jax.vmap(fun, in_axes)
U_dtheta = jax.vmap(jax.grad(u_fn), (None, 0))
U_dx = jax.vmap(gradsqz(u_fn, 1), (None, 0))
U_dddx = jax.vmap(gradsqz(gradsqz(gradsqz(u_fn, 1), 1), 1), (None, 0))

# %%
# TODO: is there a way to put these functions in a separate file?

# Source term for the KdV equation
def rhs(theta_flat, x, t):
    assert(len(x.shape) == 2)
    u = U(theta_flat, x)
    u_x = U_dx(theta_flat, x)
    u_xxx = U_dddx(theta_flat, x)
    return - u_xxx - 6 * u * u_x


@jax.jit
def M_fn(theta_flat, x):
    '''
    Assemble the M matrix (with boundary correction).
    '''
    assert(len(x.shape) == 2)
    u_dth = U_dtheta(theta_flat, x)
    M = jnp.mean(u_dth[:, :, jnp.newaxis] * u_dth[:, jnp.newaxis, :], axis=0)
    
    zeta = 10000
    x_lower, x_upper = jnp.array(problem_data.domain[0]).reshape(-1, 1), jnp.array(problem_data.domain[1]).reshape(-1, 1)
    u_dth_lower, u_dth_upper = U_dtheta(theta_flat, x_lower), U_dtheta(theta_flat, x_upper)
    u_dth_mean = jnp.mean(u_dth, axis=0).reshape(-1, 1)
    B_lower, B_upper = u_dth_lower * u_dth_mean, u_dth_upper * u_dth_mean
    B = zeta * (B_lower + B_upper)
    return M + B


@jax.jit
def F_fn(theta_flat, x, t):
    '''
    Assemble the F matrix.
    '''
    assert(len(x.shape) == 2)
    u_dth = U_dtheta(theta_flat, x)
    f = rhs(theta_flat, x, t) # source term
    F = jnp.mean(u_dth[:, :] * f[:, jnp.newaxis], axis=0)
    return F


@jax.jit
def r_fn(theta_flat, delta_theta_flat, x, t):
    '''
    Compute the local-in-time residual (with boundary correction).
    '''
    zeta = 10000
    x_lower, x_upper = jnp.array(problem_data.domain[0]).reshape(-1, 1), jnp.array(problem_data.domain[1]).reshape(-1, 1)
    
    if len(x.shape) == 0 or len(x.shape) == 1:
        # r = jnp.dot(U_dtheta(theta_flat, x.reshape(-1, 1)), delta_theta_flat) - rhs(theta_flat, x.reshape(-1, 1), t)
        r = jnp.dot((U_dtheta(theta_flat, x.reshape(-1, 1)) + zeta * (U_dtheta(theta_flat, x_lower) + U_dtheta(theta_flat, x_upper))), delta_theta_flat) - \
                rhs(theta_flat, x.reshape(-1, 1), t)
        return r.squeeze()
    
    return jnp.dot((U_dtheta(theta_flat, x) + zeta * (U_dtheta(theta_flat, x_lower) + U_dtheta(theta_flat, x_upper))), delta_theta_flat) - rhs(theta_flat, x, t)

# %%
# Test AR method for the initial sampling from u

from scipy.stats import norm

def KdVWrapper(x):
    x = jnp.array([x])
    kdv = exactKdVTwoSol(x, 0)
    return kdv.squeeze()

n = 100 # number of samples
g = norm(loc=-5, scale=4.5) # proposal distribution
C = 29 # constant for AR
x_test = sample_from_function(KdVWrapper, g, C, n)

x_plot = jnp.linspace(problem_data.domain[0], problem_data.domain[1], problem_data.N)
plt.scatter(x_test, jnp.zeros(n), color='blue', marker='.')
plt.plot(x_plot, exactKdVTwoSol(x_plot, 0))
plt.xlim([problem_data.domain[0], problem_data.domain[1]])
# plt.ylim([-0.1, 2.7])
plt.show()

# %%
# Test SVGD on a simple Gaussian

@jax.jit
def gaussian(x, mu, sigma):
    return jnp.exp(- 0.5 * (x - mu) ** 2 / sigma ** 2)

@jax.jit
def log_gaussian(x, mu, sigma):
    return jnp.log(gaussian(x, mu, sigma))

@jax.jit
def log_gaussian_dx(x, mu, sigma):
    return jax.vmap(jax.grad(log_gaussian), (0, None, None))(x, mu, sigma)

x0 = jax.random.uniform(jax.random.key(0), shape=(20, ), minval=-10, maxval=10).reshape(-1, 1) # initial particles
dlnprob = lambda x: log_gaussian_dx(x, 0, 1)
theta = SVGD_update(x0, dlnprob, n_iter=10000, stepsize=0.05, debug=True)

plt.scatter(x0, jnp.zeros_like(x0), color='blue', label='Initial particles', marker='.')
plt.scatter(theta, jnp.zeros_like(theta), color='red', label='Final particles', marker='.')
x_plot = jnp.linspace(-10, 10, 100)
plt.plot(x_plot, gaussian(x_plot, 0, 1), label='Target distribution')
plt.legend()
plt.show()
# Out:
# iter 1000
# iter 2000
# iter 3000
# iter 4000
# iter 5000
# iter 6000
# iter 7000
# iter 8000
# iter 9000
# iter 10000

# %%
def adaptive_sampling(theta_flat, problem_data, n, x, t, M_fn, F_fn, r_fn):
    '''
    Adaptive sampling with SVGD.
    '''
    alpha = 10.0 # scaling parameter... WHICH VALUE?
    gamma = 0.25 # tempering parameter
    epsilon = 0.05 # step size
    steps = 500

    # Predictor-corrector scheme
    theta_flat_pred = predictor_corrector(theta_flat, x, t, problem_data.dt, M_fn, F_fn)

    # The target measure is proportional to the residual scaled by a tempering parameter
    mu = lambda y: jnp.abs(r_fn(theta_flat, theta_flat_pred - theta_flat, y, t)) ** (2 * gamma)
    log_mu = lambda y: jnp.log(mu(y)) # log(mu) = - V
    log_mu_dx = jax.vmap(jax.grad(log_mu), 0)

    x = SVGD_update(x, log_mu_dx, n_iter=steps, stepsize=epsilon, alpha=alpha)

    return x

# %%
def runge_kutta_scheme(theta_flat, problem_data, n, x):
        
    def rhs_RK45(t, theta_flat):
        return jnp.linalg.lstsq(M_fn(theta_flat, x), F_fn(theta_flat, x, t))[0]

    # Points for plotting and error evaluation
    x_plot = jnp.linspace(problem_data.domain[0], problem_data.domain[1], problem_data.N)
    
    solution = []
    timesteps = []
    
    scheme = scipy.integrate.RK45(rhs_RK45, 0, theta_flat, problem_data.T, max_step=problem_data.dt, rtol=1e-4) # should be constant step 1e-4!

    temp_index = 0

    while scheme.t < problem_data.T:

        print(f'  t = {scheme.t:.5f}')

        # Sample points in the spatial domain
        x = adaptive_sampling(theta_flat, problem_data, n, x, scheme.t, M_fn, F_fn, r_fn)
        
        # Integration step
        scheme.step()
        timesteps.append(scheme.t)

        # Save current solution
        u = U(scheme.y, x_plot.reshape(-1, 1))
        solution.append(u)

        if temp_index % 10 == 0:
            plt.scatter(x, jnp.zeros(n), color='blue', marker='.')
            plt.plot(x_plot, exactKdVTwoSol(x_plot, scheme.t))
            plt.plot(x_plot, U(scheme.y, x_plot.reshape(-1, 1)))
            plt.xlim([-20, 40])
            plt.ylim([-0.5, 2.7])
            plt.show()

        temp_index += 1
        
    return solution, timesteps

# %%
def neural_galerkin(theta_flat, problem_data, n, sampler, scheme):

    print('Run time evolution...')

    # Initialize the particles by sampling from the initial condition
    if sampler == 'svgd':
        x_init = sample_from_function(KdVWrapper, g, C, n).reshape(-1, 1)

    solution, timesteps = runge_kutta_scheme(theta_flat, problem_data, n, x_init)

    return solution, timesteps

# %%
solution, timesteps = neural_galerkin(theta_flat=theta_flat, # parameters
                           problem_data=problem_data, # problem data
                           n=100, # sample points
                           sampler='svgd', # sampling strategy
                           scheme='rk45' # ODE solver
                          )
# Out:
# Run time evolution...
#   t = 0.00000
#   t = 0.01000
#   t = 0.02000
#   t = 0.03000
#   t = 0.04000
#   t = 0.05000
#   t = 0.06000
#   t = 0.07000
#   t = 0.08000
#   t = 0.09000
#   t = 0.10000
#   t = 0.11000
#   t = 0.12000
#   t = 0.13000
#   t = 0.14000
#   t = 0.15000
#   t = 0.16000
#   t = 0.17000
#   t = 0.18000
#   t = 0.19000
#   t = 0.20000
#   t = 0.21000
#   t = 0.22000
#   t = 0.23000
#   t = 0.24000
#   t = 0.25000
#   t = 0.26000
#   t = 0.27000
#   t = 0.28000
#   t = 0.29000
#   t = 0.30000
#   t = 0.31000
#   t = 0.32000
#   t = 0.33000
#   t = 0.34000
#   t = 0.35000
#   t = 0.36000
#   t = 0.37000
#   t = 0.38000
#   t = 0.39000
#   t = 0.40000
#   t = 0.41000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 solution, timesteps = neural_galerkin(theta_flat=theta_flat, # parameters
#       2                            problem_data=problem_data, # problem data
#       3                            n=100, # sample points
#       4                            sampler='svgd', # sampling strategy
#       5                            scheme='rk45' # ODE solver
#       6                           )
#
# Cell In[16], line 9, in neural_galerkin(theta_flat, problem_data, n, sampler, scheme)
#       6 if sampler == 'svgd':
#       7     x_init = sample_from_function(KdVWrapper, g, C, n).reshape(-1, 1)
# ----> 9 solution, timesteps = runge_kutta_scheme(theta_flat, problem_data, n, x_init)
#      11 return solution, timesteps
#
# Cell In[24], line 21, in runge_kutta_scheme(theta_flat, problem_data, n, x)
#      18 print(f'  t = {scheme.t:.5f}')
#      20 # Sample points in the spatial domain
# ---> 21 x = adaptive_sampling(theta_flat, problem_data, n, x, scheme.t, M_fn, F_fn, r_fn)
#      23 # Integration step
#      24 scheme.step()
#
# Cell In[26], line 18, in adaptive_sampling(theta_flat, problem_data, n, x, t, M_fn, F_fn, r_fn)
#      15 log_mu = lambda y: jnp.log(mu(y)) # log(mu) = - V
#      16 log_mu_dx = jax.vmap(jax.grad(log_mu), 0)
# ---> 18 x = SVGD_update(x, log_mu_dx, n_iter=steps, stepsize=epsilon, alpha=alpha)
#      20 return x
#
# File /mnt/c/Users/frabe/Desktop/EPFL/2nd-semester/semester-project/Neural_Galerkin/Sampler.py:88, in SVGD_update(x0, lnprob, n_iter, stepsize, alpha, debug)
#      85 if debug and (iter + 1) % 1000 == 0:
#      86     print('iter', str(iter + 1))
# ---> 88 lnpgrad = lnprob(theta.squeeze()).reshape(-1, 1) # lnpgrad: (n, d)
#      89 # calculating the kernel matrix
#      90 kxy, dxkxy = SVGD_kernel(theta, h=0.05) # kxy: (n, n), dxkxy: (n, d)
#
#     [... skipping hidden 1 frame]
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/api.py:1262, in vmap.<locals>.vmap_f(*args, **kwargs)
#    1259 in_axes_flat = flatten_axes("vmap in_axes", in_tree, (in_axes, 0), kws=True)
#    1260 axis_size_ = (axis_size if axis_size is not None else
#    1261               _mapped_axis_size(fun, in_tree, args_flat, in_axes_flat, "vmap"))
# -> 1262 out_flat = batching.batch(
#    1263     flat_fun, axis_name, axis_size_, in_axes_flat,
#    1264     lambda: flatten_axes("vmap out_axes", out_tree(), out_axes),
#    1265     spmd_axis_name=spmd_axis_name
#    1266 ).call_wrapped(*args_flat)
#    1267 return tree_unflatten(out_tree(), out_flat)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/linear_util.py:191, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     188 gen = gen_static_args = out_store = None
#     190 try:
# --> 191   ans = self.f(*args, **dict(self.params, **kwargs))
#     192 except:
#     193   # Some transformations yield from inside context managers, so we have to
#     194   # interrupt them before reraising the exception. Otherwise they will only
#     195   # get garbage-collected at some later time, running their cleanup tasks
#     196   # only after this exception is handled, which can corrupt the global
#     197   # state.
#     198   while stack:
#
#     [... skipping hidden 1 frame]
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/api.py:663, in grad.<locals>.grad_f(*args, **kwargs)
#     660 @wraps(fun, docstr=docstr, argnums=argnums)
#     661 @api_boundary
#     662 def grad_f(*args, **kwargs):
# --> 663   _, g = value_and_grad_f(*args, **kwargs)
#     664   return g
#
#     [... skipping hidden 1 frame]
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/api.py:739, in value_and_grad.<locals>.value_and_grad_f(*args, **kwargs)
#     737   _check_input_dtype_grad(holomorphic, allow_int, leaf)
#     738 if not has_aux:
# --> 739   ans, vjp_py = _vjp(f_partial, *dyn_args, reduce_axes=reduce_axes)
#     740 else:
#     741   ans, vjp_py, aux = _vjp(
#     742       f_partial, *dyn_args, has_aux=True, reduce_axes=reduce_axes)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/api.py:2229, in _vjp(fun, has_aux, reduce_axes, *primals)
#    2227 if not has_aux:
#    2228   flat_fun, out_tree = flatten_fun_nokwargs(fun, in_tree)
# -> 2229   out_primal, out_vjp = ad.vjp(
#    2230       flat_fun, primals_flat, reduce_axes=reduce_axes)
#    2231   out_tree = out_tree()
#    2232 else:
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:142, in vjp(traceable, primals, has_aux, reduce_axes)
#     140 def vjp(traceable, primals, has_aux=False, reduce_axes=()):
#     141   if not has_aux:
# --> 142     out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     143   else:
#     144     out_primals, pvals, jaxpr, consts, aux = linearize(traceable, *primals, has_aux=True)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:131, in linearize(traceable, *primals, **kwargs)
#     129 _, in_tree = tree_flatten(((primals, primals), {}))
#     130 jvpfun_flat, out_tree = flatten_fun(jvpfun, in_tree)
# --> 131 jaxpr, out_pvals, consts = pe.trace_to_jaxpr_nounits(jvpfun_flat, in_pvals)
#     132 out_primals_pvals, out_tangents_pvals = tree_unflatten(out_tree(), out_pvals)
#     133 assert all(out_primal_pval.is_known() for out_primal_pval in out_primals_pvals)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/profiler.py:336, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     333 @wraps(func)
#     334 def wrapper(*args, **kwargs):
#     335   with TraceAnnotation(name, **decorator_kwargs):
# --> 336     return func(*args, **kwargs)
#     337   return wrapper
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:774, in trace_to_jaxpr_nounits(fun, pvals, instantiate)
#     772 with core.new_main(JaxprTrace, name_stack=current_name_stack) as main:
#     773   fun = trace_to_subjaxpr_nounits(fun, main, instantiate)
# --> 774   jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#     775   assert not env
#     776   del main, fun, env
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/linear_util.py:191, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     188 gen = gen_static_args = out_store = None
#     190 try:
# --> 191   ans = self.f(*args, **dict(self.params, **kwargs))
#     192 except:
#     193   # Some transformations yield from inside context managers, so we have to
#     194   # interrupt them before reraising the exception. Otherwise they will only
#     195   # get garbage-collected at some later time, running their cleanup tasks
#     196   # only after this exception is handled, which can corrupt the global
#     197   # state.
#     198   while stack:
#
# Cell In[26], line 15, in adaptive_sampling.<locals>.<lambda>(y)
#      13 # The target measure is proportional to the residual scaled by a tempering parameter
#      14 mu = lambda y: jnp.abs(r_fn(theta_flat, theta_flat_pred - theta_flat, y, t)) ** (2 * gamma)
# ---> 15 log_mu = lambda y: jnp.log(mu(y)) # log(mu) = - V
#      16 log_mu_dx = jax.vmap(jax.grad(log_mu), 0)
#      18 x = SVGD_update(x, log_mu_dx, n_iter=steps, stepsize=epsilon, alpha=alpha)
#
# Cell In[26], line 14, in adaptive_sampling.<locals>.<lambda>(y)
#      11 theta_flat_pred = predictor_corrector(theta_flat, x, t, problem_data.dt, M_fn, F_fn)
#      13 # The target measure is proportional to the residual scaled by a tempering parameter
# ---> 14 mu = lambda y: jnp.abs(r_fn(theta_flat, theta_flat_pred - theta_flat, y, t)) ** (2 * gamma)
#      15 log_mu = lambda y: jnp.log(mu(y)) # log(mu) = - V
#      16 log_mu_dx = jax.vmap(jax.grad(log_mu), 0)
#
#     [... skipping hidden 1 frame]
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/pjit.py:245, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     243 @api_boundary
#     244 def cache_miss(*args, **kwargs):
# --> 245   outs, out_flat, out_tree, args_flat, jaxpr, attrs_tracked = _python_pjit_helper(
#     246       fun, infer_params_fn, *args, **kwargs)
#     247   executable = _read_most_recent_pjit_call_executable(jaxpr)
#     248   maybe_fastpath_data = _get_fastpath_data(
#     249       executable, out_tree, args_flat, out_flat, attrs_tracked)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/pjit.py:140, in _python_pjit_helper(fun, infer_params_fn, *args, **kwargs)
#     138   args_flat = [*init_states, *args_flat]
#     139 try:
# --> 140   out_flat = pjit_p.bind(*args_flat, **params)
#     141 except pxla.DeviceAssignmentMismatchError as e:
#     142   fails, = e.args
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/core.py:2743, in AxisPrimitive.bind(self, *args, **params)
#    2739 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2740                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2741 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2742              else axis_main.with_cur_sublevel())
# -> 2743 return self.bind_with_trace(top_trace, args, params)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/core.py:447, in Primitive.bind_with_trace(self, trace, args, params)
#     446 def bind_with_trace(self, trace, args, params):
# --> 447   out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     448   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:318, in JVPTrace.process_primitive(self, primitive, tracers, params)
#     316   msg = f"Differentiation rule for '{primitive}' not implemented"
#     317   raise NotImplementedError(msg)
# --> 318 primal_out, tangent_out = jvp(primals_in, tangents_in, **params)
#     319 if primitive.multiple_results:
#     320   return [JVPTracer(self, x, t) for x, t in zip(primal_out, tangent_out)]
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/pjit.py:1721, in _pjit_jvp(primals_in, tangents_in, jaxpr, in_shardings, out_shardings, resource_env, donated_invars, name, keep_unused, inline)
#    1719 _filter_zeros_in = partial(_filter_zeros, is_nz_tangents_in)
#    1720 _filter_zeros_out = partial(_filter_zeros, is_nz_tangents_out)
# -> 1721 outputs = pjit_p.bind(
#    1722     *primals_in, *_filter_zeros_in(tangents_in),
#    1723     jaxpr=jaxpr_jvp,
#    1724     in_shardings=(*in_shardings, *_filter_zeros_in(in_shardings)),
#    1725     out_shardings=(*out_shardings, *_filter_zeros_out(out_shardings)),
#    1726     resource_env=resource_env,
#    1727     donated_invars=(*donated_invars, *_filter_zeros_in(donated_invars)),
#    1728     name=name,
#    1729     keep_unused=keep_unused,
#    1730     inline=inline)
#    1732 primals_out, tangents_out = split_list(outputs, [len(jaxpr.jaxpr.outvars)])
#    1733 assert len(primals_out) == len(jaxpr.jaxpr.outvars)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/core.py:2743, in AxisPrimitive.bind(self, *args, **params)
#    2739 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2740                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2741 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2742              else axis_main.with_cur_sublevel())
# -> 2743 return self.bind_with_trace(top_trace, args, params)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/core.py:447, in Primitive.bind_with_trace(self, trace, args, params)
#     446 def bind_with_trace(self, trace, args, params):
# --> 447   out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     448   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:212, in JaxprTrace.process_primitive(self, primitive, tracers, params)
#     210 def process_primitive(self, primitive, tracers, params):
#     211   if primitive in custom_partial_eval_rules:
# --> 212     return custom_partial_eval_rules[primitive](self, *tracers, **params)
#     213   else:
#     214     return self.default_process_primitive(primitive, tracers, params)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/pjit.py:1804, in _pjit_partial_eval(trace, jaxpr, in_shardings, out_shardings, resource_env, donated_invars, name, keep_unused, inline, *in_tracers)
#    1799 all_known_outs = subs_list2(in_fwd, out_fwd, known_inputs, all_known_outs,
#    1800                             all_known_outs)
#    1802 known_out_vals, residual_vals = \
#    1803     split_list(all_known_outs, [len(all_known_outs) - num_residuals])
# -> 1804 residual_tracers = map(trace.new_instantiated_const, residual_vals)
#    1806 # The convention of partial_eval_jaxpr_nounits is to place residual binders
#    1807 # at the front of the jaxpr produced, so we move them to the back since both
#    1808 # the jaxpr equation built below and the pjit transpose rule assume a
#    1809 # residual-inputs-last convention.
#    1810 unknown_jaxpr = pe.move_binders_to_back(
#    1811     unknown_jaxpr, [True] * num_residuals + [False] * sum(unknown_ins))
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:173, in JaxprTrace.new_instantiated_const(self, val)
#     169   shape = [self.new_instantiated_const(d)
#     170            if isinstance(d, Tracer) and d._trace.level < self.level else d
#     171            for d in aval.shape]
#     172   aval = aval.update(shape=tuple(shape))
# --> 173 return JaxprTracer(self, PartialVal.unknown(aval), ConstVar(val))
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:123, in PartialVal.unknown(cls, aval)
#     121 @classmethod
#     122 def unknown(cls, aval: AbstractValue) -> PartialVal:
# --> 123   return PartialVal((aval, None))
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:108, in PartialVal.__new__(cls, xs)
#     106 def __new__(cls, xs: tuple[AbstractValue | None, core.Value]):
#     107   pv, const = xs
# --> 108   if config.enable_checks.value:
#     109     # type checks
#     110     assert isinstance(pv, (AbstractValue, type(None))), xs
#     111     assert (const is None or isinstance(const, core.Tracer) or
#     112             core.valid_jaxtype(const)), const
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/config.py:291, in _StateContextManager.value(self)
#     289 @property
#     290 def value(self) -> _T:
# --> 291   val = _thread_local_state.__dict__.get(self._name, unset)
#     292   return val if val is not unset else config._read(self._name)
#
# KeyboardInterrupt:

# %%
plot_solution(solution)

# %%
plot_animation(solution, problem_data)

# %% [markdown]
# ### Compute relative error

# %%
errors = compute_error(solution, exactKdVTwoSol, problem_data)

# %%
plot_error(errors, problem_data, 'Relative L2 error')

# %% [markdown]
# ### Comparison with static sampling

# %%
theta = jnp.load('./data/theta_init_' + problem_data.name + '_' + str(training_data.seed) + '.npy', allow_pickle=True).item()

# %%
net = DeepNetKdV(training_data.m)

# %%
theta_flat, unravel = jax.flatten_util.ravel_pytree(theta) # flatten a pytree of arrays down to a 1D array
u_fn = unraveler(net.apply, unravel) # auxiliary function that allows to evaluate the NN starting from the flattened parameters

# Define gradients
U = jax.vmap(u_fn, (None, 0)) # jax.vmap(fun, in_axes)
U_dtheta = jax.vmap(jax.grad(u_fn), (None, 0))
U_dx = jax.vmap(gradsqz(u_fn, 1), (None, 0))
U_dddx = jax.vmap(gradsqz(gradsqz(gradsqz(u_fn, 1), 1), 1), (None, 0))

# %%
# Source term for the KdV equation
def rhs(theta_flat, x, t):
    assert(len(x.shape) == 2)
    u = U(theta_flat, x)
    u_x = U_dx(theta_flat, x)
    u_xxx = U_dddx(theta_flat, x)
    return - u_xxx - 6 * u * u_x


@jax.jit
def M_fn(theta_flat, x):
    '''
    Assemble the M matrix (with boundary correction).
    '''
    assert(len(x.shape) == 2)
    u_dth = U_dtheta(theta_flat, x)
    M = jnp.mean(u_dth[:, :, jnp.newaxis] * u_dth[:, jnp.newaxis, :], axis=0)
    
    zeta = 10000
    x_lower, x_upper = jnp.array(problem_data.domain[0]).reshape(-1, 1), jnp.array(problem_data.domain[1]).reshape(-1, 1)
    u_dth_lower, u_dth_upper = U_dtheta(theta_flat, x_lower), U_dtheta(theta_flat, x_upper)
    u_dth_mean = jnp.mean(u_dth, axis=0).reshape(-1, 1)
    B_lower, B_upper = u_dth_lower * u_dth_mean, u_dth_upper * u_dth_mean
    B = zeta * (B_lower + B_upper)
    return M + B


@jax.jit
def F_fn(theta_flat, x, t):
    '''
    Assemble the F matrix.
    '''
    assert(len(x.shape) == 2)
    u_dth = U_dtheta(theta_flat, x)
    f = rhs(theta_flat, x, t) # source term
    F = jnp.mean(u_dth[:, :] * f[:, jnp.newaxis], axis=0)
    return F

# %%
solution_static, timesteps_static = neural_galerkin(theta_flat=theta_flat, # parameters
                                                    problem_data=problem_data, # problem data
                                                    n=100, # sample points
                                                    sampler='uniform', # sampling strategy
                                                    scheme='rk45' # ODE solver
                                                   )
# Out:
# Run time evolution...
#   t = 0.00000
#   t = 0.00100
#   t = 0.00200
#   t = 0.00300
#   t = 0.00400
#   t = 0.00500
#   t = 0.00600
#   t = 0.00700
#   t = 0.00800
#   t = 0.00900
#   t = 0.01000
#   t = 0.01100
#   t = 0.01200
#   t = 0.01300
#   t = 0.01400
#   t = 0.01500
#   t = 0.01600
#   t = 0.01700
#   t = 0.01800
#   t = 0.01900
#   t = 0.02000
#   t = 0.02100
#   t = 0.02200
#   t = 0.02300
#   t = 0.02400
#   t = 0.02500
#   t = 0.02600
#   t = 0.02700
#   t = 0.02800
#   t = 0.02900
#   t = 0.03000
#   t = 0.03100
#   t = 0.03200
#   t = 0.03300
#   t = 0.03400
#   t = 0.03500
#   t = 0.03600
#   t = 0.03700
#   t = 0.03800
#   t = 0.03900
#   t = 0.04000
#   t = 0.04100
#   t = 0.04200
#   t = 0.04300
#   t = 0.04400
#   t = 0.04500
#   t = 0.04600
#   t = 0.04700
#   t = 0.04800
#   t = 0.04900
#   t = 0.05000
#   t = 0.05100
#   t = 0.05200
#   t = 0.05300
#   t = 0.05400
#   t = 0.05500
#   t = 0.05600
#   t = 0.05700
#   t = 0.05800
#   t = 0.05900
#   t = 0.06000
#   t = 0.06100
#   t = 0.06200
#   t = 0.06300
#   t = 0.06400
#   t = 0.06500
#   t = 0.06600
#   t = 0.06700
#   t = 0.06800
#   t = 0.06900
#   t = 0.07000
#   t = 0.07100
#   t = 0.07200
#   t = 0.07300
#   t = 0.07400
#   t = 0.07500
#   t = 0.07600
#   t = 0.07700
#   t = 0.07800
#   t = 0.07900
#   t = 0.08000
#   t = 0.08100
#   t = 0.08200
#   t = 0.08300
#   t = 0.08400
#   t = 0.08500
#   t = 0.08600
#   t = 0.08700
#   t = 0.08800
#   t = 0.08900
#   t = 0.09000
#   t = 0.09100
#   t = 0.09200
#   t = 0.09300
#   t = 0.09400
#   t = 0.09500
#   t = 0.09600
#   t = 0.09700
#   t = 0.09800
#   t = 0.09900
#   t = 0.10000
#   t = 0.10100
#   t = 0.10200
#   t = 0.10300
#   t = 0.10400
#   t = 0.10500
#   t = 0.10600
#   t = 0.10700
#   t = 0.10800
#   t = 0.10900
#   t = 0.11000
#   t = 0.11100
#   t = 0.11200
#   t = 0.11300
#   t = 0.11400
#   t = 0.11500
#   t = 0.11600
#   t = 0.11700
#   t = 0.11800
#   t = 0.11900
#   t = 0.12000
#   t = 0.12100
#   t = 0.12200
#   t = 0.12300
#   t = 0.12400
#   t = 0.12500
#   t = 0.12600
#   t = 0.12700
#   t = 0.12800
#   t = 0.12900
#   t = 0.13000
#   t = 0.13100
#   t = 0.13200
#   t = 0.13300
#   t = 0.13400
#   t = 0.13500
#   t = 0.13600
#   t = 0.13700
#   t = 0.13800
#   t = 0.13900
#   t = 0.14000
#   t = 0.14100
#   t = 0.14200
#   t = 0.14300
#   t = 0.14400
#   t = 0.14500
#   t = 0.14600
#   t = 0.14700
#   t = 0.14800
#   t = 0.14900
#   t = 0.15000
#   t = 0.15100
#   t = 0.15200
#   t = 0.15300
#   t = 0.15400
#   t = 0.15500
#   t = 0.15600
#   t = 0.15700
#   t = 0.15800
#   t = 0.15900
#   t = 0.16000
#   t = 0.16100
#   t = 0.16200
#   t = 0.16300
#   t = 0.16400
#   t = 0.16500
#   t = 0.16600
#   t = 0.16700
#   t = 0.16800
#   t = 0.16900
#   t = 0.17000
#   t = 0.17100
#   t = 0.17200
#   t = 0.17300
#   t = 0.17400
#   t = 0.17500
#   t = 0.17600
#   t = 0.17700
#   t = 0.17800
#   t = 0.17900
#   t = 0.18000
#   t = 0.18100
#   t = 0.18200
#   t = 0.18300
#   t = 0.18400
#   t = 0.18500
#   t = 0.18600
#   t = 0.18700
#   t = 0.18800
#   t = 0.18900
#   t = 0.19000
#   t = 0.19100
#   t = 0.19200
#   t = 0.19300
#   t = 0.19400
#   t = 0.19500
#   t = 0.19600
#   t = 0.19700
#   t = 0.19800
#   t = 0.19900
#   t = 0.20000
#   t = 0.20100
#   t = 0.20200
#   t = 0.20300
#   t = 0.20400
#   t = 0.20500
#   t = 0.20600
#   t = 0.20700
#   t = 0.20800
#   t = 0.20900
#   t = 0.21000
#   t = 0.21100
#   t = 0.21200
#   t = 0.21300
#   t = 0.21400
#   t = 0.21500
#   t = 0.21600
#   t = 0.21700
#   t = 0.21800
#   t = 0.21900
#   t = 0.22000
#   t = 0.22100
#   t = 0.22200
#   t = 0.22300
#   t = 0.22400
#   t = 0.22500
#   t = 0.22600
#   t = 0.22700
#   t = 0.22800
#   t = 0.22900
#   t = 0.23000
#   t = 0.23100
#   t = 0.23200
#   t = 0.23300
#   t = 0.23400
#   t = 0.23500
#   t = 0.23600
#   t = 0.23700
#   t = 0.23800
#   t = 0.23900
#   t = 0.24000
#   t = 0.24100
#   t = 0.24200
#   t = 0.24300
#   t = 0.24400
#   t = 0.24500
#   t = 0.24600
#   t = 0.24700
#   t = 0.24800
#   t = 0.24900
#   t = 0.25000
#   t = 0.25100
#   t = 0.25200
#   t = 0.25300
#   t = 0.25400
#   t = 0.25500
#   t = 0.25600
#   t = 0.25700
#   t = 0.25800
#   t = 0.25900
#   t = 0.26000
#   t = 0.26100
#   t = 0.26200
#   t = 0.26300
#   t = 0.26400
#   t = 0.26500
#   t = 0.26600
#   t = 0.26700
#   t = 0.26800
#   t = 0.26900
#   t = 0.27000
#   t = 0.27100
#   t = 0.27200
#   t = 0.27300
#   t = 0.27400
#   t = 0.27500
#   t = 0.27600
#   t = 0.27700
#   t = 0.27800
#   t = 0.27900
#   t = 0.28000
#   t = 0.28100
#   t = 0.28200
#   t = 0.28300
#   t = 0.28400
#   t = 0.28500
#   t = 0.28600
#   t = 0.28700
#   t = 0.28800
#   t = 0.28900
#   t = 0.29000
#   t = 0.29100
#   t = 0.29200
#   t = 0.29300
#   t = 0.29400
#   t = 0.29500
#   t = 0.29600
#   t = 0.29700
#   t = 0.29800
#   t = 0.29900
#   t = 0.30000
#   t = 0.30100
#   t = 0.30200
#   t = 0.30300
#   t = 0.30400
#   t = 0.30500
#   t = 0.30600
#   t = 0.30700
#   t = 0.30800
#   t = 0.30900
#   t = 0.31000
#   t = 0.31100
#   t = 0.31200
#   t = 0.31300
#   t = 0.31400
#   t = 0.31500
#   t = 0.31600
#   t = 0.31700
#   t = 0.31800
#   t = 0.31900
#   t = 0.32000
#   t = 0.32100
#   t = 0.32200
#   t = 0.32300
#   t = 0.32400
#   t = 0.32500
#   t = 0.32600
#   t = 0.32700
#   t = 0.32800
#   t = 0.32900
#   t = 0.33000
#   t = 0.33100
#   t = 0.33200
#   t = 0.33300
#   t = 0.33400
#   t = 0.33500
#   t = 0.33600
#   t = 0.33700
#   t = 0.33800
#   t = 0.33900
#   t = 0.34000
#   t = 0.34100
#   t = 0.34200
#   t = 0.34300
#   t = 0.34400
#   t = 0.34500
#   t = 0.34600
#   t = 0.34700
#   t = 0.34800
#   t = 0.34900
#   t = 0.35000
#   t = 0.35100
#   t = 0.35200
#   t = 0.35300
#   t = 0.35400
#   t = 0.35500
#   t = 0.35600
#   t = 0.35700
#   t = 0.35800
#   t = 0.35900
#   t = 0.36000
#   t = 0.36100
#   t = 0.36200
#   t = 0.36300
#   t = 0.36400
#   t = 0.36500
#   t = 0.36600
#   t = 0.36700
#   t = 0.36800
#   t = 0.36900
#   t = 0.37000
#   t = 0.37100
#   t = 0.37200
#   t = 0.37300
#   t = 0.37400
#   t = 0.37500
#   t = 0.37600
#   t = 0.37700
#   t = 0.37800
#   t = 0.37900
#   t = 0.38000
#   t = 0.38100
#   t = 0.38200
#   t = 0.38300
#   t = 0.38400
#   t = 0.38500
#   t = 0.38600
#   t = 0.38700
#   t = 0.38800
#   t = 0.38900
#   t = 0.39000
#   t = 0.39100
#   t = 0.39200
#   t = 0.39300
#   t = 0.39400
#   t = 0.39500
#   t = 0.39600
#   t = 0.39700
#   t = 0.39800
#   t = 0.39900
#   t = 0.40000
#   t = 0.40100
#   t = 0.40200
#   t = 0.40300
#   t = 0.40400
#   t = 0.40500
#   t = 0.40600
#   t = 0.40700
#   t = 0.40800
#   t = 0.40900
#   t = 0.41000
#   t = 0.41100
#   t = 0.41200
#   t = 0.41300
#   t = 0.41400
#   t = 0.41500
#   t = 0.41600
#   t = 0.41700
#   t = 0.41800
#   t = 0.41900
#   t = 0.42000
#   t = 0.42100
#   t = 0.42200
#   t = 0.42300
#   t = 0.42400
#   t = 0.42500
#   t = 0.42600
#   t = 0.42700
#   t = 0.42800
#   t = 0.42900
#   t = 0.43000
#   t = 0.43100
#   t = 0.43200
#   t = 0.43300
#   t = 0.43400
#   t = 0.43500
#   t = 0.43600
#   t = 0.43700
#   t = 0.43800
#   t = 0.43900
#   t = 0.44000
#   t = 0.44100
#   t = 0.44200
#   t = 0.44300
#   t = 0.44400
#   t = 0.44500
#   t = 0.44600
#   t = 0.44700
#   t = 0.44800
#   t = 0.44900
#   t = 0.45000
#   t = 0.45100
#   t = 0.45200
#   t = 0.45300
#   t = 0.45400
#   t = 0.45500
#   t = 0.45600
#   t = 0.45700
#   t = 0.45800
#   t = 0.45900
#   t = 0.46000
#   t = 0.46100
#   t = 0.46200
#   t = 0.46300
#   t = 0.46400
#   t = 0.46500
#   t = 0.46600
#   t = 0.46700
#   t = 0.46800
#   t = 0.46900
#   t = 0.47000
#   t = 0.47100
#   t = 0.47200
#   t = 0.47300
#   t = 0.47400
#   t = 0.47500
#   t = 0.47600
#   t = 0.47700
#   t = 0.47800
#   t = 0.47900
#   t = 0.48000
#   t = 0.48100
#   t = 0.48200
#   t = 0.48300
#   t = 0.48400
#   t = 0.48500
#   t = 0.48600
#   t = 0.48700
#   t = 0.48800
#   t = 0.48900
#   t = 0.49000
#   t = 0.49100
#   t = 0.49200
#   t = 0.49300
#   t = 0.49400
#   t = 0.49500
#   t = 0.49600
#   t = 0.49700
#   t = 0.49800
#   t = 0.49900
#   t = 0.50000
#   t = 0.50100
#   t = 0.50200
#   t = 0.50300
#   t = 0.50400
#   t = 0.50500
#   t = 0.50600
#   t = 0.50700
#   t = 0.50800
#   t = 0.50900
#   t = 0.51000
#   t = 0.51100
#   t = 0.51200
#   t = 0.51300
#   t = 0.51400
#   t = 0.51500
#   t = 0.51600
#   t = 0.51700
#   t = 0.51800
#   t = 0.51900
#   t = 0.52000
#   t = 0.52100
#   t = 0.52200
#   t = 0.52300
#   t = 0.52400
#   t = 0.52500
#   t = 0.52600
#   t = 0.52700
#   t = 0.52800
#   t = 0.52900
#   t = 0.53000
#   t = 0.53100
#   t = 0.53200
#   t = 0.53300
#   t = 0.53400
#   t = 0.53500
#   t = 0.53600
#   t = 0.53700
#   t = 0.53800
#   t = 0.53900
#   t = 0.54000
#   t = 0.54100
#   t = 0.54200
#   t = 0.54300
#   t = 0.54400
#   t = 0.54500
#   t = 0.54600
#   t = 0.54700
#   t = 0.54800
#   t = 0.54900
#   t = 0.55000
#   t = 0.55100
#   t = 0.55200
#   t = 0.55300
#   t = 0.55400
#   t = 0.55500
#   t = 0.55600
#   t = 0.55700
#   t = 0.55800
#   t = 0.55900
#   t = 0.56000
#   t = 0.56100
#   t = 0.56200
#   t = 0.56300
#   t = 0.56400
#   t = 0.56500
#   t = 0.56600
#   t = 0.56700
#   t = 0.56800
#   t = 0.56900
#   t = 0.57000
#   t = 0.57100
#   t = 0.57200
#   t = 0.57300
#   t = 0.57400
#   t = 0.57500
#   t = 0.57600
#   t = 0.57700
#   t = 0.57800
#   t = 0.57900
#   t = 0.58000
#   t = 0.58100
#   t = 0.58200
#   t = 0.58300
#   t = 0.58400
#   t = 0.58500
#   t = 0.58600
#   t = 0.58700
#   t = 0.58800
#   t = 0.58900
#   t = 0.59000
#   t = 0.59100
#   t = 0.59200
#   t = 0.59300
#   t = 0.59400
#   t = 0.59500
#   t = 0.59600
#   t = 0.59700
#   t = 0.59800
#   t = 0.59900
#   t = 0.60000
#   t = 0.60100
#   t = 0.60200
#   t = 0.60300
#   t = 0.60400
#   t = 0.60500
#   t = 0.60600
#   t = 0.60700
#   t = 0.60800
#   t = 0.60900
#   t = 0.61000
#   t = 0.61100
#   t = 0.61200
#   t = 0.61300
#   t = 0.61400
#   t = 0.61500
#   t = 0.61600
#   t = 0.61700
#   t = 0.61800
#   t = 0.61900
#   t = 0.62000
#   t = 0.62100
#   t = 0.62200
#   t = 0.62300
#   t = 0.62400
#   t = 0.62500
#   t = 0.62600
#   t = 0.62700
#   t = 0.62800
#   t = 0.62900
#   t = 0.63000
#   t = 0.63100
#   t = 0.63200
#   t = 0.63300
#   t = 0.63400
#   t = 0.63500
#   t = 0.63600
#   t = 0.63700
#   t = 0.63800
#   t = 0.63900
#   t = 0.64000
#   t = 0.64100
#   t = 0.64200
#   t = 0.64300
#   t = 0.64400
#   t = 0.64500
#   t = 0.64600
#   t = 0.64700
#   t = 0.64800
#   t = 0.64900
#   t = 0.65000
#   t = 0.65100
#   t = 0.65200
#   t = 0.65300
#   t = 0.65400
#   t = 0.65500
#   t = 0.65600
#   t = 0.65700
#   t = 0.65800
#   t = 0.65900
#   t = 0.66000
#   t = 0.66100
#   t = 0.66200
#   t = 0.66300
#   t = 0.66400
#   t = 0.66500
#   t = 0.66600
#   t = 0.66700
#   t = 0.66800
#   t = 0.66900
#   t = 0.67000
#   t = 0.67100
#   t = 0.67200
#   t = 0.67300
#   t = 0.67400
#   t = 0.67500
#   t = 0.67600
#   t = 0.67700
#   t = 0.67800
#   t = 0.67900
#   t = 0.68000
#   t = 0.68100
#   t = 0.68200
#   t = 0.68300
#   t = 0.68400
#   t = 0.68500
#   t = 0.68600
#   t = 0.68700
#   t = 0.68800
#   t = 0.68900
#   t = 0.69000
#   t = 0.69100
#   t = 0.69200
#   t = 0.69300
#   t = 0.69400
#   t = 0.69500
#   t = 0.69600
#   t = 0.69700
#   t = 0.69800
#   t = 0.69900
#   t = 0.70000
#   t = 0.70100
#   t = 0.70200
#   t = 0.70300
#   t = 0.70400
#   t = 0.70500
#   t = 0.70600
#   t = 0.70700
#   t = 0.70800
#   t = 0.70900
#   t = 0.71000
#   t = 0.71100
#   t = 0.71200
#   t = 0.71300
#   t = 0.71400
#   t = 0.71500
#   t = 0.71600
#   t = 0.71700
#   t = 0.71800
#   t = 0.71900
#   t = 0.72000
#   t = 0.72100
#   t = 0.72200
#   t = 0.72300
#   t = 0.72400
#   t = 0.72500
#   t = 0.72600
#   t = 0.72700
#   t = 0.72800
#   t = 0.72900
#   t = 0.73000
#   t = 0.73100
#   t = 0.73200
#   t = 0.73300
#   t = 0.73400
#   t = 0.73500
#   t = 0.73600
#   t = 0.73700
#   t = 0.73800
#   t = 0.73900
#   t = 0.74000
#   t = 0.74100
#   t = 0.74200
#   t = 0.74300
#   t = 0.74400
#   t = 0.74500
#   t = 0.74600
#   t = 0.74700
#   t = 0.74800
#   t = 0.74900
#   t = 0.75000
#   t = 0.75100
#   t = 0.75200
#   t = 0.75300
#   t = 0.75400
#   t = 0.75500
#   t = 0.75600
#   t = 0.75700
#   t = 0.75800
#   t = 0.75900
#   t = 0.76000
#   t = 0.76100
#   t = 0.76200
#   t = 0.76300
#   t = 0.76400
#   t = 0.76500
#   t = 0.76600
#   t = 0.76700
#   t = 0.76800
#   t = 0.76900
#   t = 0.77000
#   t = 0.77100
#   t = 0.77200
#   t = 0.77300
#   t = 0.77400
#   t = 0.77500
#   t = 0.77600
#   t = 0.77700
#   t = 0.77800
#   t = 0.77900
#   t = 0.78000
#   t = 0.78100
#   t = 0.78200
#   t = 0.78300
#   t = 0.78400
#   t = 0.78500
#   t = 0.78600
#   t = 0.78700
#   t = 0.78800
#   t = 0.78900
#   t = 0.79000
#   t = 0.79100
#   t = 0.79200
#   t = 0.79300
#   t = 0.79400
#   t = 0.79500
#   t = 0.79600
#   t = 0.79700
#   t = 0.79800
#   t = 0.79900
#   t = 0.80000
#   t = 0.80100
#   t = 0.80200
#   t = 0.80300
#   t = 0.80400
#   t = 0.80500
#   t = 0.80600
#   t = 0.80700
#   t = 0.80800
#   t = 0.80900
#   t = 0.81000
#   t = 0.81100
#   t = 0.81200
#   t = 0.81300
#   t = 0.81400
#   t = 0.81500
#   t = 0.81600
#   t = 0.81700
#   t = 0.81800
#   t = 0.81900
#   t = 0.82000
#   t = 0.82100
#   t = 0.82200
#   t = 0.82300
#   t = 0.82400
#   t = 0.82500
#   t = 0.82600
#   t = 0.82700
#   t = 0.82800
#   t = 0.82900
#   t = 0.83000
#   t = 0.83100
#   t = 0.83200
#   t = 0.83300
#   t = 0.83400
#   t = 0.83500
#   t = 0.83600
#   t = 0.83700
#   t = 0.83800
#   t = 0.83900
#   t = 0.84000
#   t = 0.84100
#   t = 0.84200
#   t = 0.84300
#   t = 0.84400
#   t = 0.84500
#   t = 0.84600
#   t = 0.84700
#   t = 0.84800
#   t = 0.84900
#   t = 0.85000
#   t = 0.85100
#   t = 0.85200
#   t = 0.85300
#   t = 0.85400
#   t = 0.85500
#   t = 0.85600
#   t = 0.85700
#   t = 0.85800
#   t = 0.85900
#   t = 0.86000
#   t = 0.86100
#   t = 0.86200
#   t = 0.86300
#   t = 0.86400
#   t = 0.86500
#   t = 0.86600
#   t = 0.86700
#   t = 0.86800
#   t = 0.86900
#   t = 0.87000
#   t = 0.87100
#   t = 0.87200
#   t = 0.87300
#   t = 0.87400
#   t = 0.87500
#   t = 0.87600
#   t = 0.87700
#   t = 0.87800
#   t = 0.87900
#   t = 0.88000
#   t = 0.88100
#   t = 0.88200
#   t = 0.88300
#   t = 0.88400
#   t = 0.88500
#   t = 0.88600
#   t = 0.88700
#   t = 0.88800
#   t = 0.88900
#   t = 0.89000
#   t = 0.89100
#   t = 0.89200
#   t = 0.89300
#   t = 0.89400
#   t = 0.89500
#   t = 0.89600
#   t = 0.89700
#   t = 0.89800
#   t = 0.89900
#   t = 0.90000
#   t = 0.90100
#   t = 0.90200
#   t = 0.90300
#   t = 0.90400
#   t = 0.90500
#   t = 0.90600
#   t = 0.90700
#   t = 0.90800
#   t = 0.90900
#   t = 0.91000
#   t = 0.91100
#   t = 0.91200
#   t = 0.91300
#   t = 0.91400
#   t = 0.91500
#   t = 0.91600
#   t = 0.91700
#   t = 0.91800
#   t = 0.91900
#   t = 0.92000
#   t = 0.92100
#   t = 0.92200
#   t = 0.92300
#   t = 0.92400
#   t = 0.92500
#   t = 0.92600
#   t = 0.92700
#   t = 0.92800
#   t = 0.92900
#   t = 0.93000
#   t = 0.93100
#   t = 0.93200
#   t = 0.93300
#   t = 0.93400
#   t = 0.93500
#   t = 0.93600
#   t = 0.93700
#   t = 0.93800
#   t = 0.93900
#   t = 0.94000
#   t = 0.94100
#   t = 0.94200
#   t = 0.94300
#   t = 0.94400
#   t = 0.94500
#   t = 0.94600
#   t = 0.94700
#   t = 0.94800
#   t = 0.94900
#   t = 0.95000
#   t = 0.95100
#   t = 0.95200
#   t = 0.95300
#   t = 0.95400
#   t = 0.95500
#   t = 0.95600
#   t = 0.95700
#   t = 0.95800
#   t = 0.95900
#   t = 0.96000
#   t = 0.96100
#   t = 0.96200
#   t = 0.96300
#   t = 0.96400
#   t = 0.96500
#   t = 0.96600
#   t = 0.96700
#   t = 0.96800
#   t = 0.96900
#   t = 0.97000
#   t = 0.97100
#   t = 0.97200
#   t = 0.97300
#   t = 0.97400
#   t = 0.97500
#   t = 0.97600
#   t = 0.97700
#   t = 0.97800
#   t = 0.97900
#   t = 0.98000
#   t = 0.98100
#   t = 0.98200
#   t = 0.98300
#   t = 0.98400
#   t = 0.98500
#   t = 0.98600
#   t = 0.98700
#   t = 0.98800
#   t = 0.98900
#   t = 0.99000
#   t = 0.99100
#   t = 0.99200
#   t = 0.99300
#   t = 0.99400
#   t = 0.99500
#   t = 0.99600
#   t = 0.99700
#   t = 0.99800
#   t = 0.99900
#   t = 1.00000
#   t = 1.00100
#   t = 1.00200
#   t = 1.00300
#   t = 1.00400
#   t = 1.00500
#   t = 1.00600
#   t = 1.00700
#   t = 1.00800
#   t = 1.00900
#   t = 1.01000
#   t = 1.01100
#   t = 1.01200
#   t = 1.01300
#   t = 1.01400
#   t = 1.01500
#   t = 1.01600
#   t = 1.01700
#   t = 1.01800
#   t = 1.01900
#   t = 1.02000
#   t = 1.02100
#   t = 1.02200
#   t = 1.02300
#   t = 1.02400
#   t = 1.02500
#   t = 1.02600
#   t = 1.02700
#   t = 1.02800
#   t = 1.02900
#   t = 1.03000
#   t = 1.03100
#   t = 1.03200
#   t = 1.03300
#   t = 1.03400
#   t = 1.03500
#   t = 1.03600
#   t = 1.03700
#   t = 1.03800
#   t = 1.03900
#   t = 1.04000
#   t = 1.04100
#   t = 1.04200
#   t = 1.04300
#   t = 1.04400
#   t = 1.04500
#   t = 1.04600
#   t = 1.04700
#   t = 1.04800
#   t = 1.04900
#   t = 1.05000
#   t = 1.05100
#   t = 1.05200
#   t = 1.05300
#   t = 1.05400
#   t = 1.05500
#   t = 1.05600
#   t = 1.05700
#   t = 1.05800
#   t = 1.05900
#   t = 1.06000
#   t = 1.06100
#   t = 1.06200
#   t = 1.06300
#   t = 1.06400
#   t = 1.06500
#   t = 1.06600
#   t = 1.06700
#   t = 1.06800
#   t = 1.06900
#   t = 1.07000
#   t = 1.07100
#   t = 1.07200
#   t = 1.07300
#   t = 1.07400
#   t = 1.07500
#   t = 1.07600
#   t = 1.07700
#   t = 1.07800
#   t = 1.07900
#   t = 1.08000
#   t = 1.08100
#   t = 1.08200
#   t = 1.08300
#   t = 1.08400
#   t = 1.08500
#   t = 1.08600
#   t = 1.08700
#   t = 1.08800
#   t = 1.08900
#   t = 1.09000
#   t = 1.09100
#   t = 1.09200
#   t = 1.09300
#   t = 1.09400
#   t = 1.09500
#   t = 1.09600
#   t = 1.09700
#   t = 1.09800
#   t = 1.09900
#   t = 1.10000
#   t = 1.10100
#   t = 1.10200
#   t = 1.10300
#   t = 1.10400
#   t = 1.10500
#   t = 1.10600
#   t = 1.10700
#   t = 1.10800
#   t = 1.10900
#   t = 1.11000
#   t = 1.11100
#   t = 1.11200
#   t = 1.11300
#   t = 1.11400
#   t = 1.11500
#   t = 1.11600
#   t = 1.11700
#   t = 1.11800
#   t = 1.11900
#   t = 1.12000
#   t = 1.12100
#   t = 1.12200
#   t = 1.12300
#   t = 1.12400
#   t = 1.12500
#   t = 1.12600
#   t = 1.12700
#   t = 1.12800
#   t = 1.12900
#   t = 1.13000
#   t = 1.13100
#   t = 1.13200
#   t = 1.13300
#   t = 1.13400
#   t = 1.13500
#   t = 1.13600
#   t = 1.13700
#   t = 1.13800
#   t = 1.13900
#   t = 1.14000
#   t = 1.14100
#   t = 1.14200
#   t = 1.14300
#   t = 1.14400
#   t = 1.14500
#   t = 1.14600
#   t = 1.14700
#   t = 1.14800
#   t = 1.14900
#   t = 1.15000
#   t = 1.15100
#   t = 1.15200
#   t = 1.15300
#   t = 1.15400
#   t = 1.15500
#   t = 1.15600
#   t = 1.15700
#   t = 1.15800
#   t = 1.15900
#   t = 1.16000
#   t = 1.16100
#   t = 1.16200
#   t = 1.16300
#   t = 1.16400
#   t = 1.16500
#   t = 1.16600
#   t = 1.16700
#   t = 1.16800
#   t = 1.16900
#   t = 1.17000
#   t = 1.17100
#   t = 1.17200
#   t = 1.17300
#   t = 1.17400
#   t = 1.17500
#   t = 1.17600
#   t = 1.17700
#   t = 1.17800
#   t = 1.17900
#   t = 1.18000
#   t = 1.18100
#   t = 1.18200
#   t = 1.18300
#   t = 1.18400
#   t = 1.18500
#   t = 1.18600
#   t = 1.18700
#   t = 1.18800
#   t = 1.18900
#   t = 1.19000
#   t = 1.19100
#   t = 1.19200
#   t = 1.19300
#   t = 1.19400
#   t = 1.19500
#   t = 1.19600
#   t = 1.19700
#   t = 1.19800
#   t = 1.19900
#   t = 1.20000
#   t = 1.20100
#   t = 1.20200
#   t = 1.20300
#   t = 1.20400
#   t = 1.20500
#   t = 1.20600
#   t = 1.20700
#   t = 1.20800
#   t = 1.20900
#   t = 1.21000
#   t = 1.21100
#   t = 1.21200
#   t = 1.21300
#   t = 1.21400
#   t = 1.21500
#   t = 1.21600
#   t = 1.21700
#   t = 1.21800
#   t = 1.21900
#   t = 1.22000
#   t = 1.22100
#   t = 1.22200
#   t = 1.22300
#   t = 1.22400
#   t = 1.22500
#   t = 1.22600
#   t = 1.22700
#   t = 1.22800
#   t = 1.22900
#   t = 1.23000
#   t = 1.23100
#   t = 1.23200
#   t = 1.23300
#   t = 1.23400
#   t = 1.23500
#   t = 1.23600
#   t = 1.23700
#   t = 1.23800
#   t = 1.23900
#   t = 1.24000
#   t = 1.24100
#   t = 1.24200
#   t = 1.24300
#   t = 1.24400
#   t = 1.24500
#   t = 1.24600
#   t = 1.24700
#   t = 1.24800
#   t = 1.24900
#   t = 1.25000
#   t = 1.25100
#   t = 1.25200
#   t = 1.25300
#   t = 1.25400
#   t = 1.25500
#   t = 1.25600
#   t = 1.25700
#   t = 1.25800
#   t = 1.25900
#   t = 1.26000
#   t = 1.26100
#   t = 1.26200
#   t = 1.26300
#   t = 1.26400
#   t = 1.26500
#   t = 1.26600
#   t = 1.26700
#   t = 1.26800
#   t = 1.26900
#   t = 1.27000
#   t = 1.27100
#   t = 1.27200
#   t = 1.27300
#   t = 1.27400
#   t = 1.27500
#   t = 1.27600
#   t = 1.27700
#   t = 1.27800
#   t = 1.27900
#   t = 1.28000
#   t = 1.28100
#   t = 1.28200
#   t = 1.28300
#   t = 1.28400
#   t = 1.28500
#   t = 1.28600
#   t = 1.28700
#   t = 1.28800
#   t = 1.28900
#   t = 1.29000
#   t = 1.29100
#   t = 1.29200
#   t = 1.29300
#   t = 1.29400
#   t = 1.29500
#   t = 1.29600
#   t = 1.29700
#   t = 1.29800
#   t = 1.29900
#   t = 1.30000
#   t = 1.30100
#   t = 1.30200
#   t = 1.30300
#   t = 1.30400
#   t = 1.30500
#   t = 1.30600
#   t = 1.30700
#   t = 1.30800
#   t = 1.30900
#   t = 1.31000
#   t = 1.31100
#   t = 1.31200
#   t = 1.31300
#   t = 1.31400
#   t = 1.31500
#   t = 1.31600
#   t = 1.31700
#   t = 1.31800
#   t = 1.31900
#   t = 1.32000
#   t = 1.32100
#   t = 1.32200
#   t = 1.32300
#   t = 1.32400
#   t = 1.32500
#   t = 1.32600
#   t = 1.32700
#   t = 1.32800
#   t = 1.32900
#   t = 1.33000
#   t = 1.33100
#   t = 1.33200
#   t = 1.33300
#   t = 1.33400
#   t = 1.33500
#   t = 1.33600
#   t = 1.33700
#   t = 1.33800
#   t = 1.33900
#   t = 1.34000
#   t = 1.34100
#   t = 1.34200
#   t = 1.34300
#   t = 1.34400
#   t = 1.34500
#   t = 1.34600
#   t = 1.34700
#   t = 1.34800
#   t = 1.34900
#   t = 1.35000
#   t = 1.35100
#   t = 1.35200
#   t = 1.35300
#   t = 1.35400
#   t = 1.35500
#   t = 1.35600
#   t = 1.35700
#   t = 1.35800
#   t = 1.35900
#   t = 1.36000
#   t = 1.36100
#   t = 1.36200
#   t = 1.36300
#   t = 1.36400
#   t = 1.36500
#   t = 1.36600
#   t = 1.36700
#   t = 1.36800
#   t = 1.36900
#   t = 1.37000
#   t = 1.37100
#   t = 1.37200
#   t = 1.37300
#   t = 1.37400
#   t = 1.37500
#   t = 1.37600
#   t = 1.37700
#   t = 1.37800
#   t = 1.37900
#   t = 1.38000
#   t = 1.38100
#   t = 1.38200
#   t = 1.38300
#   t = 1.38400
#   t = 1.38500
#   t = 1.38600
#   t = 1.38700
#   t = 1.38800
#   t = 1.38900
#   t = 1.39000
#   t = 1.39100
#   t = 1.39200
#   t = 1.39300
#   t = 1.39400
#   t = 1.39500
#   t = 1.39600
#   t = 1.39700
#   t = 1.39800
#   t = 1.39900
#   t = 1.40000
#   t = 1.40100
#   t = 1.40200
#   t = 1.40300
#   t = 1.40400
#   t = 1.40500
#   t = 1.40600
#   t = 1.40700
#   t = 1.40800
#   t = 1.40900
#   t = 1.41000
#   t = 1.41100
#   t = 1.41200
#   t = 1.41300
#   t = 1.41400
#   t = 1.41500
#   t = 1.41600
#   t = 1.41700
#   t = 1.41800
#   t = 1.41900
#   t = 1.42000
#   t = 1.42100
#   t = 1.42200
#   t = 1.42300
#   t = 1.42400
#   t = 1.42500
#   t = 1.42600
#   t = 1.42700
#   t = 1.42800
#   t = 1.42900
#   t = 1.43000
#   t = 1.43100
#   t = 1.43200
#   t = 1.43300
#   t = 1.43400
#   t = 1.43500
#   t = 1.43600
#   t = 1.43700
#   t = 1.43800
#   t = 1.43900
#   t = 1.44000
#   t = 1.44100
#   t = 1.44200
#   t = 1.44300
#   t = 1.44400
#   t = 1.44500
#   t = 1.44600
#   t = 1.44700
#   t = 1.44800
#   t = 1.44900
#   t = 1.45000
#   t = 1.45100
#   t = 1.45200
#   t = 1.45300
#   t = 1.45400
#   t = 1.45500
#   t = 1.45600
#   t = 1.45700
#   t = 1.45800
#   t = 1.45900
#   t = 1.46000
#   t = 1.46100
#   t = 1.46200
#   t = 1.46300
#   t = 1.46400
#   t = 1.46500
#   t = 1.46600
#   t = 1.46700
#   t = 1.46800
#   t = 1.46900
#   t = 1.47000
#   t = 1.47100
#   t = 1.47200
#   t = 1.47300
#   t = 1.47400
#   t = 1.47500
#   t = 1.47600
#   t = 1.47700
#   t = 1.47800
#   t = 1.47900
#   t = 1.48000
#   t = 1.48100
#   t = 1.48200
#   t = 1.48300
#   t = 1.48400
#   t = 1.48500
#   t = 1.48600
#   t = 1.48700
#   t = 1.48800
#   t = 1.48900
#   t = 1.49000
#   t = 1.49100
#   t = 1.49200
#   t = 1.49300
#   t = 1.49400
#   t = 1.49500
#   t = 1.49600
#   t = 1.49700
#   t = 1.49800
#   t = 1.49900
#   t = 1.50000
#   t = 1.50100
#   t = 1.50200
#   t = 1.50300
#   t = 1.50400
#   t = 1.50500
#   t = 1.50600
#   t = 1.50700
#   t = 1.50800
#   t = 1.50900
#   t = 1.51000
#   t = 1.51100
#   t = 1.51200
#   t = 1.51300
#   t = 1.51400
#   t = 1.51500
#   t = 1.51600
#   t = 1.51700
#   t = 1.51800
#   t = 1.51900
#   t = 1.52000
#   t = 1.52100
#   t = 1.52200
#   t = 1.52300
#   t = 1.52400
#   t = 1.52500
#   t = 1.52600
#   t = 1.52700
#   t = 1.52800
#   t = 1.52900
#   t = 1.53000
#   t = 1.53100
#   t = 1.53200
#   t = 1.53300
#   t = 1.53400
#   t = 1.53500
#   t = 1.53600
#   t = 1.53700
#   t = 1.53800
#   t = 1.53900
#   t = 1.54000
#   t = 1.54100
#   t = 1.54200
#   t = 1.54300
#   t = 1.54400
#   t = 1.54500
#   t = 1.54600
#   t = 1.54700
#   t = 1.54800
#   t = 1.54900
#   t = 1.55000
#   t = 1.55100
#   t = 1.55200
#   t = 1.55300
#   t = 1.55400
#   t = 1.55500
#   t = 1.55600
#   t = 1.55700
#   t = 1.55800
#   t = 1.55900
#   t = 1.56000
#   t = 1.56100
#   t = 1.56200
#   t = 1.56300
#   t = 1.56400
#   t = 1.56500
#   t = 1.56600
#   t = 1.56700
#   t = 1.56800
#   t = 1.56900
#   t = 1.57000
#   t = 1.57100
#   t = 1.57200
#   t = 1.57300
#   t = 1.57400
#   t = 1.57500
#   t = 1.57600
#   t = 1.57700
#   t = 1.57800
#   t = 1.57900
#   t = 1.58000
#   t = 1.58100
#   t = 1.58200
#   t = 1.58300
#   t = 1.58400
#   t = 1.58500
#   t = 1.58600
#   t = 1.58700
#   t = 1.58800
#   t = 1.58900
#   t = 1.59000
#   t = 1.59100
#   t = 1.59200
#   t = 1.59300
#   t = 1.59400
#   t = 1.59500
#   t = 1.59600
#   t = 1.59700
#   t = 1.59800
#   t = 1.59900
#   t = 1.60000
#   t = 1.60100
#   t = 1.60200
#   t = 1.60300
#   t = 1.60400
#   t = 1.60500
#   t = 1.60600
#   t = 1.60700
#   t = 1.60800
#   t = 1.60900
#   t = 1.61000
#   t = 1.61100
#   t = 1.61200
#   t = 1.61300
#   t = 1.61400
#   t = 1.61500
#   t = 1.61600
#   t = 1.61700
#   t = 1.61800
#   t = 1.61900
#   t = 1.62000
#   t = 1.62100
#   t = 1.62200
#   t = 1.62300
#   t = 1.62400
#   t = 1.62500
#   t = 1.62600
#   t = 1.62700
#   t = 1.62800
#   t = 1.62900
#   t = 1.63000
#   t = 1.63100
#   t = 1.63200
#   t = 1.63300
#   t = 1.63400
#   t = 1.63500
#   t = 1.63600
#   t = 1.63700
#   t = 1.63800
#   t = 1.63900
#   t = 1.64000
#   t = 1.64100
#   t = 1.64200
#   t = 1.64300
#   t = 1.64400
#   t = 1.64500
#   t = 1.64600
#   t = 1.64700
#   t = 1.64800
#   t = 1.64900
#   t = 1.65000
#   t = 1.65100
#   t = 1.65200
#   t = 1.65300
#   t = 1.65400
#   t = 1.65500
#   t = 1.65600
#   t = 1.65700
#   t = 1.65800
#   t = 1.65900
#   t = 1.66000
#   t = 1.66100
#   t = 1.66200
#   t = 1.66300
#   t = 1.66400
#   t = 1.66500
#   t = 1.66600
#   t = 1.66700
#   t = 1.66800
#   t = 1.66900
#   t = 1.67000
#   t = 1.67100
#   t = 1.67200
#   t = 1.67300
