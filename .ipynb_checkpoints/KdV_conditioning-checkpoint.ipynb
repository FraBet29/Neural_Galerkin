# %% [markdown]
# # KdV equation

# %%
import sys
import os
sys.path.append("./src")

# %%
import jax
import jax.numpy as jnp
import optax
from Data import *
from Plot import *
from NeuralNetwork import *
from InitialFit import *
from Solver import *
import time

# %% [markdown]
# ### Setup

# %%
# Exact solution

def exactKdVTwoSol(x, t):
    '''
    Function taken from https://github.com/pehersto/ng/solvers/exactKdV.py
    Args:
        x: jnp.array, points in space
        t: jnp.array (or float), points in time
    '''

    k = jnp.asarray([1., jnp.sqrt(5.)])
    eta = jnp.asarray([0., 10.73])
    t = jnp.asarray(t) # in case t is a float

    etaMat1 = k[0] * x.reshape((-1, 1)) - k[0] ** 3 * t.reshape((1, -1)) + eta[0]
    etaMat2 = k[1] * x.reshape((-1, 1)) - k[1] ** 3 * t.reshape((1, -1)) + eta[1]
    c = ((k[0] - k[1]) / (k[0] + k[1]) )** 2

    f = 1. + jnp.exp(etaMat1) + jnp.exp(etaMat2) + jnp.multiply(jnp.exp(etaMat1), jnp.exp(etaMat2) * c)
    df = k[0] * jnp.exp(etaMat1) + k[1] * jnp.exp(etaMat2) + c * (k[0] + k[1]) * jnp.multiply(jnp.exp(etaMat1), jnp.exp(etaMat2))
    ddf = k[0] ** 2 * jnp.exp(etaMat1) + k[1] ** 2 * jnp.exp(etaMat2) + c * (k[0] + k[1]) ** 2 * jnp.multiply(jnp.exp(etaMat1), jnp.exp(etaMat2))

    y = 2 * jnp.divide(jnp.multiply(f, ddf) - df ** 2, f ** 2)

    y = jnp.nan_to_num(y, nan=0.0, posinf=0.0, neginf=0.0) # avoid numerical errors far outside of [-1, 2]
    
    return y

# %%
# Problem and training data

problem_data = ProblemData(name='kdv', # problem name
                           d=1, # input dimension
                           domain=(-20, 40), # 1D: (lower, upper)
                           T=4, # final time
                           initial_fn=lambda x: exactKdVTwoSol(x, 0), # initial condition
                           exact_sol=exactKdVTwoSol, # exact solution
                           N=2048, # number of spatial points
                           dt=1.0, # time step (not needed here, we use an adaptive step with RK45)
                          )

training_data = TrainingData(m=10, # number of neurons per layer
                             l=1, # number of layers
                             batch_size=5000, # batch size
                             epochs=10000, # number of epochs
                             gamma=0.1, # learning rate
                             seed=0, # seed for reproducibility
                             scheduler=optax.exponential_decay(init_value=0.1, transition_steps=1000, decay_rate=0.9) # learning rate scheduler
                             # scheduler=optax.linear_schedule(init_value=0.1, end_value=0.001, 
                             #                                 transition_steps=1000, transition_begin=1000) # learning rate scheduler
                             # scheduler=optax.piecewise_constant_schedule(init_value=0.1, boundaries_and_scales={1000: 0.1}) # learning rate scheduler
                            )

# %%
# Neural network

net = ShallowNetKdV(training_data.m, problem_data.domain[1] - problem_data.domain[0])
print(net)
# Out:
# ShallowNetKdV(
#     # attributes
#     m = 10
#     L = 60
# )

# %% [markdown]
# ### Initial fit

# %%
# Initial fit

initial_fit = False # True to train a NN to fit the initial condition, False otherwise

if initial_fit:
    theta = init_neural_galerkin(net, problem_data, training_data) # train a NN to fit the initial condition
    jnp.save('./data/theta_init_' + problem_data.name + '_' + str(training_data.seed) + '.npy', theta)
else:
    theta = jnp.load('./data/theta_init_' + problem_data.name + '_' + str(training_data.seed) + '.npy', allow_pickle=True).item()
    x_plot = jnp.linspace(problem_data.domain[0], problem_data.domain[1], problem_data.N)
    relative_error = jnp.linalg.norm(net.apply(theta, x_plot.reshape(-1, 1)) - exactKdVTwoSol(x_plot, 0)) / jnp.linalg.norm(exactKdVTwoSol(x_plot, 0))
    print("Relative error of the initial fit:", relative_error)
# Out:
# An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.
# Relative error of the initial fit: 0.0059745763

# %% [markdown]
# ### Time evolution

# %%
# Source term for the KdV equation

def rhs_kdv(theta_flat, x, t, u_fn):
    U = jax.vmap(u_fn, (None, 0)) # jax.vmap(fun, in_axes)
    U_dx = jax.vmap(gradsqz(u_fn, 1), (None, 0))
    U_dddx = jax.vmap(gradsqz(gradsqz(gradsqz(u_fn, 1), 1), 1), (None, 0))
    u = U(theta_flat, x)
    u_x = U_dx(theta_flat, x)
    u_xxx = U_dddx(theta_flat, x)
    return - u_xxx - 6 * u * u_x

# %%
solution, timesteps, diagnostic = neural_galerkin(theta=theta, # initial parameters
                                                  net=net, # neural network
                                                  problem_data=problem_data, # problem data
                                                  n=1000, # sample points
                                                  rhs=rhs_kdv, # problem RHS
                                                  x_init=None,
                                                  sampler='uniform',
                                                  scheme='rk45',
                                                  diagnostic_on=True, # save conditioning number and singular values of the mass matrix
                                                 )

# %%
plot_solution(solution, timesteps, problem_data)

# %%
diagnostic.plot(timesteps)

# %% [markdown]
# ### Conditioning number w.r.t. number of samples

# %%
solution, timesteps, diagnostic = neural_galerkin(theta=theta, # initial parameters
                                                  net=net, # neural network
                                                  problem_data=problem_data, # problem data
                                                  n=16000, # sample points
                                                  rhs=rhs_kdv, # problem RHS
                                                  x_init=None,
                                                  sampler='uniform',
                                                  scheme='rk45',
                                                  diagnostic_on=True, # save conditioning number and singular values of the mass matrix
                                                  seed=4000
                                                 )
# Out:
# Elapsed time: 109.854 s

# %%
diagnostic.averaged()[0]
# Out:
# Array(9.235051e+13, dtype=float32)

# %%
# samples_list = [1000, 2000, 4000, 8000, 16000, 24000, 32000, 48000, 64000]
samples_list = [32000]
time_list = []
cond_list = []
# max_eig_list = []
# min_eig_list = []

for samples in samples_list:

    print(f'Running model with {samples} samples...')
    
    time_sum = 0.0
    cond_list_int = []
    cond_nan = 0
    
    for i in range(5): # repeat each run 5 times
        start = time.time()
        solution, timesteps, diagnostic = neural_galerkin(theta=theta, # initial parameters
                                                          net=net, # neural network
                                                          problem_data=problem_data, # problem data
                                                          n=samples, # sample points
                                                          rhs=rhs_kdv, # problem RHS
                                                          x_init=None,
                                                          sampler='uniform',
                                                          scheme='rk45',
                                                          diagnostic_on=True, # save conditioning number and singular values of the mass matrix
                                                          plot_on=False,
                                                          seed=1000*i
                                                         )
        end = time.time()
        time_sum += end - start
        cond = diagnostic.averaged()[0]
        if jnp.isnan(cond):
            cond_nan += 1
        else:
            cond_list_int.append(cond)
    
    print(f'{cond_nan} NaN condition numbers detected.')
    print(cond_list_int)
    time_list.append(time_sum / 5.0)
    cond_list.append(cond_list_int)
    # avg_cond, avg_max_eig, avg_min_eig = diagnostic.averaged()
    # cond_list.append(avg_cond)
    # max_eig_list.append(avg_max_eig)
    # min_eig_list.append(avg_min_eig)
# Out:
# Running model with 32000 samples...
# Run time evolution...
# Elapsed time: 191.389 s
# Run time evolution...
# Elapsed time: 141.243 s
# Run time evolution...
# Elapsed time: 158.911 s
# Run time evolution...
# Elapsed time: 169.557 s
# Run time evolution...
# Elapsed time: 105.848 s
# 0 NaN condition numbers detected.
# [Array(1.260837e+13, dtype=float32), Array(1.879964e+13, dtype=float32), Array(9.914307e+12, dtype=float32), Array(1.2441332e+13, dtype=float32), Array(9.988002e+12, dtype=float32)]

# %%
# 1 NaN condition numbers detected with n = 32000
# 3 NaN condition numbers detected with n = 48000
# 4 NaN condition numbers detected with n = 64000

# %%
samples_list = [1000, 2000, 4000, 8000, 16000, 24000, 32000, 48000, 64000]
cond_list = [[2.333777e+13, 8.9458626e+14, 9.2429005e+13, 1.823527e+14, 1.0469402e+13],
             [2.2445073e+14, 4.746919e+15, 3.2812506e+13, 4.3798114e+14, 4.9339783e+13],
             [5.724211e+14, 5.310578e+12, 5.621322e+12, 2.4177927e+13, 2.3636147e+13],
             [6.739443e+12, 2.465955e+13, 1.2345669e+13, 9.423549e+12, 8.546667e+13],
             [5.196893e+12, 3.8218762e+13, 9.44217e+12, 3.34404e+13, 9.235051e+13],
             [1.260837e+13, 1.879964e+13, 9.914307e+12, 1.2441332e+13, 9.988002e+12],
             [1.260837e+13, 1.879964e+13, 1.2441332e+13, 9.988002e+12],
             [1.7309767e+13, 7.789299e+12],
             [1.6906957e+13]
            ]

cond_avg = [jnp.mean(jnp.array(cond)) for cond in cond_list]
for idx, samples in enumerate(samples_list):
    for c in range(len(cond_list[idx])):
        plt.scatter(samples, cond_list[idx][c], c='b')
plt.plot(samples_list, cond_avg, 'r-*')
plt.title('Conditioning number of M vs number of samples')
plt.xlabel('samples')
plt.ylabel('cond(M)')
# plt.xscale('log')
plt.yscale('log')
plt.show()

# %%
samples_list = [1000, 2000, 4000, 8000, 16000, 32000, 48000, 64000]
time_list = [25.454, 27.745, 26.007, 38.407, 70.641, 169.298, 196, 298.438]
plt.plot(samples_list, time_list, 'o-')
plt.title('Elapsed time vs number of samples')
plt.xlabel('samples')
plt.ylabel('time')
plt.show()

# %%
# plt.plot(samples_list, max_eig_list)
# plt.plot(samples_list, min_eig_list)
# plt.title('Eigenvalues of M vs number of samples')
# plt.xlabel('samples')
# plt.ylabel('eigenvalues')
# plt.legend(['max', 'min'])
# plt.show()

# %% [markdown]
# ### Conditioning number w.r.t. number of parameters

# %%
# Set the training parameters to achieve an initial error of around 0.005
# m = 10 (baseline): batch_size = 5000, epochs = 10000, gamma = 0.1, scheduler = exponential_decay(init_value=0.1, transition_steps=1000, decay_rate=0.9)
# m = 15: batch_size = 5000, epochs = 10000, gamma = 0.1, scheduler = exponential_decay(init_value=0.1, transition_steps=1000, decay_rate=0.9)
# m = 20: batch_size = 1000, epochs = 10000, gamma = 0.1, scheduler = exponential_decay(init_value=0.1, transition_steps=1000, decay_rate=0.9)
# m = 25: batch_size = 1000, epochs = 7000, gamma = 0.1, scheduler = exponential_decay(init_value=0.1, transition_steps=1000, decay_rate=0.9)

# %%
neurons = 25

training_data = TrainingData(m=neurons, # number of neurons per layer
                             l=1, # number of layers
                             batch_size=500, # batch size
                             epochs=5000, # number of epochs
                             gamma=0.1, # learning rate
                             seed=0, # seed for reproducibility
                             scheduler=optax.exponential_decay(init_value=0.1, transition_steps=1000, decay_rate=0.9) # learning rate scheduler
                            )

net = ShallowNetKdV(training_data.m, problem_data.domain[1] - problem_data.domain[0])

initial_fit = False # True to train a NN to fit the initial condition, False otherwise

if initial_fit:
    theta = init_neural_galerkin(net, problem_data, training_data) # train a NN to fit the initial condition
    jnp.save('./data/theta_init_' + problem_data.name + '_' + str(training_data.seed) + '_' + str(neurons) + '.npy', theta)

# %%
# neurons_list = [10, 15, 20, 25]
neurons_list = [25]
time_list = []
cond_list = []
# max_eig_list = []
# min_eig_list = []

for neurons in neurons_list:

    print(f'Running model with {neurons} neurons...')

    if neurons == 10:
        theta = jnp.load('./data/theta_init_' + problem_data.name + '_' + str(training_data.seed) + '.npy', allow_pickle=True).item() # baseline
    else:
        theta = jnp.load('./data/theta_init_' + problem_data.name + '_' + str(training_data.seed) + '_' + str(neurons) + '.npy', allow_pickle=True).item()

    net = ShallowNetKdV(neurons, problem_data.domain[1] - problem_data.domain[0])

    time_sum, cond_sum = 0.0, 0.0
    cond_nan = 0
    
    for i in range(5):
        start = time.time()
        solution, timesteps, diagnostic = neural_galerkin(theta=theta, # initial parameters
                                                          net=net, # neural network
                                                          problem_data=problem_data, # problem data
                                                          n=1000, # sample points
                                                          rhs=rhs_kdv, # problem RHS
                                                          x_init=None,
                                                          sampler='uniform',
                                                          scheme='rk45',
                                                          diagnostic_on=True, # save conditioning number and singular values of the mass matrix
                                                          plot_on=False,
                                                          seed=1000*i
                                                         )
        end = time.time()
        time_sum += end - start
        cond = diagnostic.averaged()[0]
        if jnp.isnan(cond):
            cond_nan += 1
        else:
            cond_sum += cond

    print(f'{cond_nan} NaN condition numbers detected.')
    time_list.append(time_sum / 5.0)
    cond_list.append(cond_sum / (5.0 - cond_nan))
    # avg_cond, avg_max_eig, avg_min_eig = diagnostic.averaged()
    # cond_list.append(avg_cond)
    # max_eig_list.append(avg_max_eig)
    # min_eig_list.append(avg_min_eig)

# %%
# 1 NaN condition numbers detected with m = 15

# %%
neurons_list = [10, 15, 20, 25]
cond_list = [2.4063502e+14, 5.525942e+15, jnp.inf, 7.8124766e+20]
plt.semilogy(neurons_list, cond_list, 'o-')
plt.title('Conditioning number of M vs number of neurons')
plt.xlabel('m')
plt.ylabel('cond(M)')
plt.show()

# %%
neurons_list = [10, 15, 20, 25]
time_list = [27.283, 43.340, 34.113, 32.677]
plt.plot(neurons_list, time_list, 'o-')
plt.title('Elapsed time vs number of neurons')
plt.xlabel('m')
plt.ylabel('time')
plt.show()

# %%
# plt.plot(neurons_list, max_eig_list)
# plt.plot(neurons_list, min_eig_list)
# plt.title('Eigenvalues of M vs number of neurons')
# plt.xlabel('m')
# plt.ylabel('eigenvalues')
# plt.legend(['max', 'min'])
# plt.show()

# %% [markdown]
# ### Comparison with Neural Galerkin with adaptive measure

# %%
# Accept-reject to sample from the initial condition

from scipy.stats import norm, uniform
from numpy import random

def init_samples_kdv(n, max_it=1000, seed=0):

    random.seed(seed) # set seed for reproducibility

    def KdVWrapper(x):
        x = jnp.array([x])
        kdv = exactKdVTwoSol(x, 0)
        return kdv.squeeze()

    g = norm(loc=-5, scale=4.5) # proposal distribution
    C = 29 # scaling constant

    x = []

    for _ in range(n):
        it = 0
        while it < max_it:
            y = g.rvs() # sample from the Gaussian
            u = uniform.rvs() # sample from a uniform in [0, 1]
            if u <= KdVWrapper(y) / (C * g.pdf(y)):
                x.append(y)
                break
            it += 1
        if it >= max_it:
            raise Exception("AR did not converge.")

    return jnp.array(x)

# %%
# Built-in SciPy function to sample from the initial condition (DOES NOT WORK - ONLY FOR UNIMODAL DISTRIBUTIONS)

# from scipy.stats.sampling import TransformedDensityRejection

# def KdVWrapper(x):
#     x = jnp.array([x])
#     kdv = exactKdVTwoSol(x, 0)
#     return kdv.squeeze()

# dist = Distribution(pdf=KdVWrapper)
# rng = TransformedDensityRejection(dist, domain=(problem_data.domain[0], problem_data.domain[1]))
# rvs = rng.rvs(100)

# x_plot = jnp.linspace(problem_data.domain[0], problem_data.domain[1], 100)
# plt.plot(x_plot, exactKdVTwoSol(x_plot.reshape(-1, 1)))
# plt.plot(rvs, jnp.zeros(100))
# plt.show()

# %%
# ORIGINAL SVGD

solution_adaptive, timesteps_adaptive, diagnostic_adaptive = neural_galerkin(theta=theta, # initial parameters
                                                                             net=net, # neural network
                                                                             problem_data=problem_data, # problem data
                                                                             n=100, # sample points
                                                                             rhs=rhs_kdv, # problem RHS
                                                                             x_init=init_samples_kdv(100).reshape(-1, 1), # particles
                                                                             sampler='svgd',
                                                                             scheme='rk45',
                                                                             diagnostic_on=True, # save conditioning number and singular values of the mass matrix
                                                                            )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 3
#       1 # ORIGINAL SVGD
# ----> 3 solution_adaptive, timesteps_adaptive, diagnostic_adaptive = neural_galerkin(theta=theta, # initial parameters
#       4                                                                              net=net, # neural network
#       5                                                                              problem_data=problem_data, # problem data
#       6                                                                              n=100, # sample points
#       7                                                                              rhs=rhs_kdv, # problem RHS
#       8                                                                              x_init=init_samples_kdv(100).reshape(-1, 1), # particles
#       9                                                                              sampler='svgd',
#      10                                                                              scheme='rk45',
#      11                                                                              diagnostic_on=True, # save conditioning number and singular values of the mass matrix
#      12                                                                             )
#
# File /mnt/c/Users/frabe/Desktop/EPFL/2nd-semester/semester-project/Neural_Galerkin/./src/Solver.py:265, in neural_galerkin(theta, net, problem_data, n, rhs, x_init, sampler, scheme, diagnostic_on, plot_on)
#     262 start = time.time()
#     264 if scheme == 'rk45':
# --> 265     solution, timesteps, diagnostic = runge_kutta_scheme(theta_flat, problem_data, n, u_fn, rhs, x_init, sampler, diagnostic_on, plot_on)
#     266 elif scheme == 'bwe':
#     267     # solution, timesteps, diagnostic = backward_euler_scheme(theta_flat, problem_data, n, u_fn, rhs, x_init, sampler, diagnostic_on, plot_on)
#     268     raise NotImplementedError('Backward Euler scheme is not implemented yet.')
#
# File /mnt/c/Users/frabe/Desktop/EPFL/2nd-semester/semester-project/Neural_Galerkin/./src/Solver.py:76, in runge_kutta_scheme(theta_flat, problem_data, n, u_fn, rhs, x_init, sampler, diagnostic_on, plot_on)
#      74     x = uniform_sampling(problem_data, n, int(scheme.t * 1e6))
#      75 elif sampler == 'svgd':
# ---> 76     x = adaptive_sampling(u_fn, rhs, scheme.y, problem_data, x, scheme.t, gamma=0.25, epsilon=0.05, steps=250,
#      77                           diagnostic_on=diagnostic_on)
#      78 elif sampler == 'svgd_corrected':
#      79     x = adaptive_sampling(u_fn, rhs, scheme.y, problem_data, x, scheme.t, gamma=0.25, epsilon=0.05, steps=250,
#      80                           corrected=True, diagnostic_on=diagnostic_on)
#
# File /mnt/c/Users/frabe/Desktop/EPFL/2nd-semester/semester-project/Neural_Galerkin/./src/Sampler.py:344, in adaptive_sampling(u_fn, rhs, theta_flat, problem_data, x, t, gamma, epsilon, steps, corrected, diagnostic_on)
#     340         x = SVGD_update_unbiased(x, log_mu_dx, steps, epsilon, alpha, diagnostic_on=diagnostic_on)
#     341     else:
#     342         # x = SVGD_update(x, log_mu_dx, steps, epsilon, alpha, diagnostic_on=diagnostic_on)
#     343         # x = SVGD_update_adaptive(x, log_mu_dx, alpha=alpha, diagnostic_on=diagnostic_on)
# --> 344         x = high_order_runge_kutta(x, mu, alpha=alpha, diagnostic_on=diagnostic_on)
#     346     # x = svgd(x, log_mu_dx, T=steps, eta=epsilon)
#     347     # x = svgd_unbiased(x, log_mu_dx, T=steps, eta=epsilon)
#     348
#     349 	# Constrain the particles in the spatial domain
#     350     x = jnp.clip(x, problem_data.domain[0], problem_data.domain[1])
#
# File /mnt/c/Users/frabe/Desktop/EPFL/2nd-semester/semester-project/Neural_Galerkin/./src/Sampler.py:234, in high_order_runge_kutta(x0, mu, T, h, alpha, diagnostic_on)
#     231     return x
#     233 for t in range(T):
# --> 234     x = runge_kutta_step(x, t)
#     235     if diagnostic_on:
#     236         wass.append(wasserstein_1d(x_old.squeeze(), x.squeeze(), p=2))
#
# File /mnt/c/Users/frabe/Desktop/EPFL/2nd-semester/semester-project/Neural_Galerkin/./src/Sampler.py:227, in high_order_runge_kutta.<locals>.runge_kutta_step(x, t)
#     226 def runge_kutta_step(x, t):
# --> 227     csi = jax.random.normal(jax.random.PRNGKey(t * 100), (x.shape[0], ))
#     228     y1 = x + jnp.sqrt(2 * h) * sigma * csi
#     229     y2 = x - 3/8 * h * f(y1) + jnp.sqrt(2 * h) * sigma * csi / 4
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/jax/_src/random.py:241, in PRNGKey(seed, impl)
#     224 def PRNGKey(seed: int | ArrayLike, *,
#     225             impl: PRNGSpecDesc | None = None) -> KeyArray:
#     226   """Create a pseudo-random number generator (PRNG) key given an integer seed.
#     227
#     228   The resulting key carries the default PRNG implementation, as
#    (...)
#     239     and ``fold_in``.
#     240   """
# --> 241   return _return_prng_keys(True, _key('PRNGKey', seed, impl))
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/jax/_src/random.py:203, in _key(ctor_name, seed, impl_spec)
#     199 if np.ndim(seed):
#     200   raise TypeError(
#     201       f"{ctor_name} accepts a scalar seed, but was given an array of "
#     202       f"shape {np.shape(seed)} != (). Use jax.vmap for batching")
# --> 203 return prng.random_seed(seed, impl=impl)
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/jax/_src/prng.py:634, in random_seed(seeds, impl)
#     629 def random_seed(seeds: int | typing.ArrayLike, impl: PRNGImpl) -> PRNGKeyArray:
#     630   # Avoid overflow error in X32 mode by first converting ints to int64.
#     631   # This breaks JIT invariance for large ints, but supports the common
#     632   # use-case of instantiating with Python hashes in X32 mode.
#     633   if isinstance(seeds, int):
# --> 634     seeds_arr = jnp.asarray(np.int64(seeds))
#     635   else:
#     636     seeds_arr = jnp.asarray(seeds)
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/jax/_src/numpy/lax_numpy.py:2242, in asarray(a, dtype, order, copy)
#    2240 if dtype is not None:
#    2241   dtype = dtypes.canonicalize_dtype(dtype, allow_extended_dtype=True)  # type: ignore[assignment]
# -> 2242 return array(a, dtype=dtype, copy=bool(copy), order=order)
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/jax/_src/numpy/lax_numpy.py:2197, in array(object, dtype, copy, order, ndmin)
#    2194 else:
#    2195   raise TypeError(f"Unexpected input type for array: {type(object)}")
# -> 2197 out_array: Array = lax_internal._convert_element_type(
#    2198     out, dtype, weak_type=weak_type)
#    2199 if ndmin > ndim(out_array):
#    2200   out_array = lax.expand_dims(out_array, range(ndmin - ndim(out_array)))
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/jax/_src/lax/lax.py:558, in _convert_element_type(operand, new_dtype, weak_type)
#     556   return type_cast(Array, operand)
#     557 else:
# --> 558   return convert_element_type_p.bind(operand, new_dtype=new_dtype,
#     559                                      weak_type=bool(weak_type))
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/jax/_src/core.py:422, in Primitive.bind(self, *args, **params)
#     419 def bind(self, *args, **params):
#     420   assert (not config.enable_checks.value or
#     421           all(isinstance(arg, Tracer) or valid_jaxtype(arg) for arg in args)), args
# --> 422   return self.bind_with_trace(find_top_trace(args), args, params)
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/jax/_src/core.py:425, in Primitive.bind_with_trace(self, trace, args, params)
#     424 def bind_with_trace(self, trace, args, params):
# --> 425   out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     426   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/jax/_src/core.py:913, in EvalTrace.process_primitive(self, primitive, tracers, params)
#     912 def process_primitive(self, primitive, tracers, params):
# --> 913   return primitive.impl(*tracers, **params)
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/jax/_src/dispatch.py:87, in apply_primitive(prim, *args, **params)
#      85 prev = lib.jax_jit.swap_thread_local_state_disable_jit(False)
#      86 try:
# ---> 87   outs = fun(*args)
#      88 finally:
#      89   lib.jax_jit.swap_thread_local_state_disable_jit(prev)
#
# KeyboardInterrupt:

# %%
plot_solution(solution_adaptive, timesteps_adaptive, problem_data)

# %%
diagnostic_adaptive.plot(timesteps_adaptive)

# %%
# CORRECTED SVGD

solution_adaptive, timesteps_adaptive, diagnostic_adaptive = neural_galerkin(theta=theta, # initial parameters
                                                                             net=net, # neural network
                                                                             problem_data=problem_data, # problem data
                                                                             n=100, # sample points
                                                                             rhs=rhs_kdv, # problem RHS
                                                                             x_init=init_samples_kdv(100).reshape(-1, 1), # particles
                                                                             sampler='svgd_corrected',
                                                                             scheme='rk45',
                                                                             diagnostic_on=True, # save conditioning number and singular values of the mass matrix
                                                                            )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 3
#       1 # CORRECTED SVGD
# ----> 3 solution_adaptive, timesteps_adaptive, diagnostic_adaptive = neural_galerkin(theta=theta, # initial parameters
#       4                                                                              net=net, # neural network
#       5                                                                              problem_data=problem_data, # problem data
#       6                                                                              n=100, # sample points
#       7                                                                              rhs=rhs_kdv, # problem RHS
#       8                                                                              x_init=init_samples_kdv(100).reshape(-1, 1), # particles
#       9                                                                              sampler='svgd_corrected',
#      10                                                                              scheme='rk45',
#      11                                                                              diagnostic_on=True, # save conditioning number and singular values of the mass matrix
#      12                                                                             )
#
# File /mnt/c/Users/frabe/Desktop/EPFL/2nd-semester/semester-project/Neural_Galerkin/./src/Solver.py:271, in neural_galerkin(theta, net, problem_data, n, rhs, x_init, sampler, scheme, diagnostic_on, plot_on)
#     268 start = time.time()
#     270 if scheme == 'rk45':
# --> 271     solution, timesteps, diagnostic = runge_kutta_scheme(theta_flat, problem_data, n, u_fn, rhs, x_init, sampler, diagnostic_on, plot_on)
#     272 elif scheme == 'bwe':
#     273     # solution, timesteps, diagnostic = backward_euler_scheme(theta_flat, problem_data, n, u_fn, rhs, x_init, sampler, diagnostic_on, plot_on)
#     274     raise NotImplementedError('Backward Euler scheme is not implemented yet.')
#
# File /mnt/c/Users/frabe/Desktop/EPFL/2nd-semester/semester-project/Neural_Galerkin/./src/Solver.py:85, in runge_kutta_scheme(theta_flat, problem_data, n, u_fn, rhs, x_init, sampler, diagnostic_on, plot_on)
#      82     x = adaptive_sampling(u_fn, rhs, scheme.y, problem_data, x, scheme.t, gamma=0.25, epsilon=0.05, steps=250,
#      83                           diagnostic_on=diagnostic_on)
#      84 elif sampler == 'svgd_corrected':
# ---> 85     x = adaptive_sampling(u_fn, rhs, scheme.y, problem_data, x, scheme.t, gamma=0.25, epsilon=0.05, steps=250,
#      86                           corrected=True, diagnostic_on=diagnostic_on)
#      87 elif sampler == 'weighted':
#      88     x, w_fn = weighted_sampling(u_fn, scheme.y, problem_data, x, gamma=0.25, epsilon=0.05, steps=250)
#
# File /mnt/c/Users/frabe/Desktop/EPFL/2nd-semester/semester-project/Neural_Galerkin/./src/Sampler.py:264, in adaptive_sampling(u_fn, rhs, theta_flat, problem_data, x, t, gamma, epsilon, steps, corrected, diagnostic_on)
#     261 log_mu_dx = jax.vmap(jax.grad(log_mu), 0)
#     263 if corrected:
# --> 264     x = SVGD_update_unbiased(x, log_mu_dx, steps, epsilon, alpha, diagnostic_on=diagnostic_on)
#     265 else:
#     266     x = SVGD_update(x, log_mu_dx, steps, epsilon, alpha, diagnostic_on=diagnostic_on)
#
# File /mnt/c/Users/frabe/Desktop/EPFL/2nd-semester/semester-project/Neural_Galerkin/./src/Sampler.py:149, in SVGD_update_unbiased(z0, log_mu_dx, steps, epsilon, alpha, diagnostic_on)
#     145     wass = []
#     147 for s in range(steps):
# --> 149     log_mu_dx_val = log_mu_dx(z.squeeze()).reshape(-1, 1) # log_mu_dx: (n, d)
#     150     # Calculating the kernel matrix
#     151     kxy, dxkxy = SVGD_kernel(z, h=0.05) # kxy: (n, n), dxkxy: (n, d)
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/jax/_src/api.py:1240, in vmap.<locals>.vmap_f(*args, **kwargs)
#    1237 in_axes_flat = flatten_axes("vmap in_axes", in_tree, (in_axes, 0), kws=True)
#    1238 axis_size_ = (axis_size if axis_size is not None else
#    1239               _mapped_axis_size(fun, in_tree, args_flat, in_axes_flat, "vmap"))
# -> 1240 out_flat = batching.batch(
#    1241     flat_fun, axis_name, axis_size_, in_axes_flat,
#    1242     lambda: flatten_axes("vmap out_axes", out_tree(), out_axes),
#    1243     spmd_axis_name=spmd_axis_name
#    1244 ).call_wrapped(*args_flat)
#    1245 return tree_unflatten(out_tree(), out_flat)
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/jax/_src/linear_util.py:192, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     189 gen = gen_static_args = out_store = None
#     191 try:
# --> 192   ans = self.f(*args, **dict(self.params, **kwargs))
#     193 except:
#     194   # Some transformations yield from inside context managers, so we have to
#     195   # interrupt them before reraising the exception. Otherwise they will only
#     196   # get garbage-collected at some later time, running their cleanup tasks
#     197   # only after this exception is handled, which can corrupt the global
#     198   # state.
#     199   while stack:
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/jax/_src/api.py:647, in grad.<locals>.grad_f(*args, **kwargs)
#     644 @wraps(fun, docstr=docstr, argnums=argnums)
#     645 @api_boundary
#     646 def grad_f(*args, **kwargs):
# --> 647   _, g = value_and_grad_f(*args, **kwargs)
#     648   return g
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/jax/_src/api.py:723, in value_and_grad.<locals>.value_and_grad_f(*args, **kwargs)
#     721 _check_scalar(ans)
#     722 tree_map(partial(_check_output_dtype_grad, holomorphic), ans)
# --> 723 g = vjp_py(lax_internal._one(ans))
#     724 g = g[0] if isinstance(argnums, int) else g
#     725 if not has_aux:
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/jax/_src/tree_util.py:485, in _HashableCallableShim.__call__(self, *args, **kw)
#     484 def __call__(self, *args, **kw):
# --> 485   return self.fun(*args, **kw)
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/jax/_src/api.py:2135, in _vjp_pullback_wrapper(name, cotangent_dtypes, cotangent_shapes, io_tree, fun, *py_args_)
#    2130   if np.shape(arg) != ct_shape:
#    2131     raise ValueError(
#    2132         f"Shape of cotangent input to vjp pullback function {np.shape(arg)} "
#    2133         "must be the same as the shape of corresponding primal input "
#    2134         f"{ct_shape}.")
# -> 2135 ans = fun(*args)
#    2136 return tree_unflatten(out_tree, ans)
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/jax/_src/tree_util.py:485, in _HashableCallableShim.__call__(self, *args, **kw)
#     484 def __call__(self, *args, **kw):
# --> 485   return self.fun(*args, **kw)
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/jax/_src/interpreters/ad.py:150, in vjp.<locals>.unbound_vjp(pvals, jaxpr, consts, *cts)
#     148 cts = tuple(ct for ct, pval in zip(cts, pvals) if not pval.is_known())
#     149 dummy_args = [UndefinedPrimal(v.aval) for v in jaxpr.invars]
# --> 150 arg_cts = backward_pass(jaxpr, True, consts, dummy_args, cts)
#     151 return map(instantiate_zeros, arg_cts)
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/jax/_src/interpreters/ad.py:249, in backward_pass(jaxpr, transform_stack, consts, primals_in, cotangents_in)
#     246   cts_out = get_primitive_transpose(eqn.primitive)(
#     247       params, call_jaxpr, invals, cts_in, cts_in_avals)
#     248 elif eqn.primitive in reducing_transposes:
# --> 249   cts_out = reducing_transposes[eqn.primitive](
#     250       cts_in, *invals, **eqn.params)
#     251 else:
#     252   cts_out = get_primitive_transpose(eqn.primitive)(
#     253       cts_in, *invals, **eqn.params)
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/jax/_src/pjit.py:1963, in _pjit_transpose(cts_in, jaxpr, in_shardings, out_shardings, resource_env, donated_invars, name, keep_unused, inline, *primals_in)
#    1957 body, cts_out_treedef_thunk = flatten_fun_nokwargs(body, in_treedef)
#    1959 transpose_in_shardings = (
#    1960   *prune_type(ad.UndefinedPrimal, in_shardings, primals_in),
#    1961   *prune_type(ad.Zero, out_shardings, cts_in)
#    1962 )
# -> 1963 global_cts_in_avals = tuple(core.raise_to_shaped(core.get_aval(ct))
#    1964                             for ct in primals_and_nz_cts_in)
#    1966 transpose_jaxpr, attrs_tracked = _pjit_transpose_trace(
#    1967     body, global_cts_in_avals)
#    1968 cts_out_treedef = cts_out_treedef_thunk()
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/jax/_src/pjit.py:1963, in <genexpr>(.0)
#    1957 body, cts_out_treedef_thunk = flatten_fun_nokwargs(body, in_treedef)
#    1959 transpose_in_shardings = (
#    1960   *prune_type(ad.UndefinedPrimal, in_shardings, primals_in),
#    1961   *prune_type(ad.Zero, out_shardings, cts_in)
#    1962 )
# -> 1963 global_cts_in_avals = tuple(core.raise_to_shaped(core.get_aval(ct))
#    1964                             for ct in primals_and_nz_cts_in)
#    1966 transpose_jaxpr, attrs_tracked = _pjit_transpose_trace(
#    1967     body, global_cts_in_avals)
#    1968 cts_out_treedef = cts_out_treedef_thunk()
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/jax/_src/core.py:1478, in get_aval(x)
#    1476 def get_aval(x):
#    1477   if isinstance(x, Tracer):
# -> 1478     return x.aval
#    1479   else:
#    1480     return concrete_aval(x)
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/jax/_src/interpreters/batching.py:333, in BatchTracer.aval(self)
#     331 @property
#     332 def aval(self):
# --> 333   aval = raise_to_shaped(core.get_aval(self.val))
#     334   if self.batch_dim is not_mapped:
#     335     return aval
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/jax/_src/core.py:1480, in get_aval(x)
#    1478   return x.aval
#    1479 else:
# -> 1480   return concrete_aval(x)
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/jax/_src/core.py:1469, in concrete_aval(x)
#    1467 for typ in type(x).__mro__:
#    1468   handler = pytype_aval_mappings.get(typ)
# -> 1469   if handler: return handler(x)
#    1470 if hasattr(x, '__jax_array__'):
#    1471   return concrete_aval(x.__jax_array__())
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/jax/_src/abstract_arrays.py:46, in canonical_concrete_aval(val, weak_type)
#      45 def canonical_concrete_aval(val, weak_type=None):
# ---> 46   return ConcreteArray(dtypes.canonicalize_dtype(np.result_type(val)), val,
#      47                        weak_type=weak_type)
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/jax/_src/core.py:1721, in ConcreteArray.__init__(self, dtype, val, weak_type)
#    1718 def __init__(self, dtype, val, weak_type=None):
#    1719   super().__init__(
#    1720       np.shape(val), dtype,
# -> 1721       weak_type=dtypes.is_weakly_typed(val) if weak_type is None else weak_type)
#    1722   dtypes.check_valid_dtype(self.dtype)
#    1723   # Note: canonicalized self.dtype doesn't necessarily match self.val
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/jax/_src/dtypes.py:625, in is_weakly_typed(x)
#     622   b_tp = cast(JAXType, b if any(b is t for t in _weak_types) else np.dtype(b))
#     623   return np.dtype(_least_upper_bound(config.numpy_dtype_promotion.value, a_tp, b_tp))
# --> 625 def is_weakly_typed(x: Any) -> bool:
#     626   if type(x) in _weak_types:
#     627     return True
#
# KeyboardInterrupt:

# %% [markdown]
# ### Conditioning number w.r.t. number of samples

# %%
# samples_list_adaptive = [100, 200, 400, 800]
# cond_list_adaptive = []
# max_eig_list_adaptive = []
# min_eig_list_adaptive = []

# for samples in samples_list_adaptive:
#     solution, timesteps, diagnostic = neural_galerkin(theta=theta, # initial parameters
#                                                       net=net, # neural network
#                                                       problem_data=problem_data, # problem data
#                                                       n=samples, # sample points
#                                                       rhs=rhs_kdv, # problem RHS
#                                                       x_init=None,
#                                                       sampler='uniform',
#                                                       scheme='rk45',
#                                                       diagnostic_on=True, # save conditioning number and singular values of the mass matrix
#                                                       plot_on=False
#                                                      )
#     avg_cond, avg_max_eig, avg_min_eig = diagnostic.averaged()
#     cond_list_adaptive.append(avg_cond)
#     max_eig_list_adaptive.append(avg_max_eig)
#     min_eig_list_adaptive.append(avg_min_eig)
