# %% [markdown]
# # KdV equation

# %%
import sys
import os
sys.path.append("./src")

# %%
import jax
import jax.numpy as jnp
import optax
from Data import *
from Plot import *
from NeuralNetwork import *
from InitialFit import *
from Solver import *
# Out:
# An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.

# %% [markdown]
# ### Setup

# %%
# Exact solution

def exactKdVTwoSol(x, t):
    '''
    Function taken from https://github.com/pehersto/ng/solvers/exactKdV.py
    Args:
        x: jnp.array, points in space
        t: jnp.array (or float), points in time
    '''

    k = jnp.asarray([1., jnp.sqrt(5.)])
    eta = jnp.asarray([0., 10.73])
    t = jnp.asarray(t) # in case t is a float

    etaMat1 = k[0] * x.reshape((-1, 1)) - k[0] ** 3 * t.reshape((1, -1)) + eta[0]
    etaMat2 = k[1] * x.reshape((-1, 1)) - k[1] ** 3 * t.reshape((1, -1)) + eta[1]
    c = ((k[0] - k[1]) / (k[0] + k[1]) )** 2

    f = 1. + jnp.exp(etaMat1) + jnp.exp(etaMat2) + jnp.multiply(jnp.exp(etaMat1), jnp.exp(etaMat2) * c)
    df = k[0] * jnp.exp(etaMat1) + k[1] * jnp.exp(etaMat2) + c * (k[0] + k[1]) * jnp.multiply(jnp.exp(etaMat1), jnp.exp(etaMat2))
    ddf = k[0] ** 2 * jnp.exp(etaMat1) + k[1] ** 2 * jnp.exp(etaMat2) + c * (k[0] + k[1]) ** 2 * jnp.multiply(jnp.exp(etaMat1), jnp.exp(etaMat2))

    y = 2 * jnp.divide(jnp.multiply(f, ddf) - df ** 2, f ** 2)

    y = jnp.nan_to_num(y, nan=0.0, posinf=0.0, neginf=0.0) # avoid numerical errors far outside of [-1, 2]
    
    return y

# %%
# Problem and training data

problem_data = ProblemData(name='kdv', # problem name
                           d=1, # input dimension
                           domain=(-20, 40), # 1D: (lower, upper)
                           T=4, # final time
                           initial_fn=lambda x: exactKdVTwoSol(x, 0), # initial condition
                           exact_sol=exactKdVTwoSol, # exact solution
                           N=2048, # number of spatial points
                           dt=1.0, # time step (not needed here, we use an adaptive step with RK45)
                          )

training_data = TrainingData(m=10, # number of neurons per layer
                             l=1, # number of layers
                             batch_size=5000, # batch size
                             epochs=10000, # number of epochs
                             gamma=0.1, # learning rate
                             seed=0, # seed for reproducibility
                             scheduler=optax.exponential_decay(init_value=0.1, transition_steps=1000, decay_rate=0.9) # learning rate scheduler
                             # scheduler=optax.linear_schedule(init_value=0.1, end_value=0.001, 
                             #                                 transition_steps=1000, transition_begin=1000) # learning rate scheduler
                             # scheduler=optax.piecewise_constant_schedule(init_value=0.1, boundaries_and_scales={1000: 0.1}) # learning rate scheduler
                            )

# %%
plot_function(problem_data.initial_fn, problem_data, 'Exact initial condition')

# %%
print(problem_data)
# Out:
# Problem data:
#   name: kdv, d: 1, domain: (-20, 40), T: 4, N: 2048, dt: 1.0

# %%
print(training_data)
# Out:
# Training data:
#   m: 10, l: 1, batch size: 5000, epochs: 10000, gamma: 0.1, seed: 0, scheduler: <function exponential_decay.<locals>.schedule at 0x7f953cf0f420>

# %%
# Neural network

net = ShallowNetKdV(training_data.m, problem_data.domain[1] - problem_data.domain[0])
print(net)
# Out:
# ShallowNetKdV(
#     # attributes
#     m = 10
#     L = 60
# )

# %% [markdown]
# ### Initial fit

# %%
# Initial fit

initial_fit = False # True to train a NN to fit the initial condition, False otherwise

if initial_fit:
    theta = init_neural_galerkin(net, problem_data, training_data) # train a NN to fit the initial condition
    jnp.save('./data/theta_init_' + problem_data.name + '_' + str(training_data.seed) + '.npy', theta)
else:
    theta = jnp.load('./data/theta_init_' + problem_data.name + '_' + str(training_data.seed) + '.npy', allow_pickle=True).item()
    x_plot = jnp.linspace(problem_data.domain[0], problem_data.domain[1], problem_data.N)
    relative_error = jnp.linalg.norm(net.apply(theta, x_plot.reshape(-1, 1)) - exactKdVTwoSol(x_plot, 0)) / jnp.linalg.norm(exactKdVTwoSol(x_plot, 0))
    print("Relative error of the initial fit:", relative_error)
# Out:
# Relative error of the initial fit: 0.0059745763

# %% [markdown]
# ### Time evolution

# %%
# Source term for the KdV equation

def rhs_kdv(theta_flat, x, t, u_fn):
    U = jax.vmap(u_fn, (None, 0)) # jax.vmap(fun, in_axes)
    U_dx = jax.vmap(gradsqz(u_fn, 1), (None, 0))
    U_dddx = jax.vmap(gradsqz(gradsqz(gradsqz(u_fn, 1), 1), 1), (None, 0))
    u = U(theta_flat, x)
    u_x = U_dx(theta_flat, x)
    u_xxx = U_dddx(theta_flat, x)
    return - u_xxx - 6 * u * u_x

# %%
solution, timesteps, _ = neural_galerkin(theta=theta, # initial parameters
                                         net=net, # neural network
                                         problem_data=problem_data, # problem data
                                         n=1000, # sample points
                                         rhs=rhs_kdv, # problem RHS
                                         x_init=None,
                                         sampler='weighted',
                                         scheme='rk45'
                                        )
# Out:
# cond(M) = 4157528800.0
# cond(M) = 4796058000.0
# cond(M) = 1562632300.0
# cond(M) = 3944360700.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 solution, timesteps, _ = neural_galerkin(theta=theta, # initial parameters
#       2                                          net=net, # neural network
#       3                                          problem_data=problem_data, # problem data
#       4                                          n=1000, # sample points
#       5                                          rhs=rhs_kdv, # problem RHS
#       6                                          x_init=None,
#       7                                          sampler='weighted',
#       8                                          scheme='rk45'
#       9                                         )
#
# File /mnt/c/Users/frabe/Desktop/EPFL/2nd-semester/semester-project/Neural_Galerkin/./src/Solver.py:268, in neural_galerkin(theta, net, problem_data, n, rhs, x_init, sampler, scheme, diagnostic_on, plot_on)
#     265 start = time.time()
#     267 if scheme == 'rk45':
# --> 268     solution, timesteps, diagnostic = runge_kutta_scheme(theta_flat, problem_data, n, u_fn, rhs, x_init, sampler, diagnostic_on, plot_on)
#     269 elif scheme == 'bwe':
#     270     # solution, timesteps, diagnostic = backward_euler_scheme(theta_flat, problem_data, n, u_fn, rhs, x_init, sampler, diagnostic_on, plot_on)
#     271     raise NotImplementedError('Backward Euler scheme is not implemented yet.')
#
# File /mnt/c/Users/frabe/Desktop/EPFL/2nd-semester/semester-project/Neural_Galerkin/./src/Solver.py:98, in runge_kutta_scheme(theta_flat, problem_data, n, u_fn, rhs, x_init, sampler, diagnostic_on, plot_on)
#      95     diagnostic.min_eig.append(jnp.min(eigs))
#      97 # Integration step
# ---> 98 scheme.step()
#     100 if plot_on and it % 10 == 0:
#     102     plot1 = plt.scatter(x, - 0.1 * jnp.ones(n), color='blue', marker='.')
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/scipy/integrate/_ivp/base.py:197, in OdeSolver.step(self)
#     195 else:
#     196     t = self.t
# --> 197     success, message = self._step_impl()
#     199     if not success:
#     200         self.status = 'failed'
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/scipy/integrate/_ivp/rk.py:144, in RungeKutta._step_impl(self)
#     141 h = t_new - t
#     142 h_abs = np.abs(h)
# --> 144 y_new, f_new = rk_step(self.fun, t, y, self.f, h, self.A,
#     145                        self.B, self.C, self.K)
#     146 scale = atol + np.maximum(np.abs(y), np.abs(y_new)) * rtol
#     147 error_norm = self._estimate_error_norm(self.K, h, scale)
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/scipy/integrate/_ivp/rk.py:64, in rk_step(fun, t, y, f, h, A, B, C, K)
#      62 for s, (a, c) in enumerate(zip(A[1:], C[1:]), start=1):
#      63     dy = np.dot(K[:s].T, a[:s]) * h
# ---> 64     K[s] = fun(t + c * h, y + dy)
#      66 y_new = y + h * np.dot(K[:-1].T, B)
#      67 f_new = fun(t + h, y_new)
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/scipy/integrate/_ivp/base.py:154, in OdeSolver.__init__.<locals>.fun(t, y)
#     152 def fun(t, y):
#     153     self.nfev += 1
# --> 154     return self.fun_single(t, y)
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/scipy/integrate/_ivp/base.py:23, in check_arguments.<locals>.fun_wrapped(t, y)
#      22 def fun_wrapped(t, y):
# ---> 23     return np.asarray(fun(t, y), dtype=dtype)
#
# File /mnt/c/Users/frabe/Desktop/EPFL/2nd-semester/semester-project/Neural_Galerkin/./src/Solver.py:41, in runge_kutta_scheme.<locals>.rhs_rk45(t, theta_flat)
#      39 def rhs_rk45(t, theta_flat):
#      40     if sampler == 'weighted':
# ---> 41         M, F = assemble_weighted(u_fn, rhs, theta_flat, x, t, w_fn)
#      42         return jnp.linalg.lstsq(M, F)[0]
#      43         # return jnp.linalg.lstsq(M_fn_weighted(u_fn, theta_flat, x, w_fn), F_fn_weighted(u_fn, rhs, theta_flat, x, t, w_fn))[0]
#      44     else:
#
# File /mnt/c/Users/frabe/Desktop/EPFL/2nd-semester/semester-project/Neural_Galerkin/./src/Assemble.py:92, in assemble_weighted(u_fn, rhs, theta_flat, x, t, w_fn)
#      90 U_dtheta = jax.vmap(jax.grad(u_fn), (None, 0))
#      91 u_dth = U_dtheta(theta_flat, x)
# ---> 92 u_dth_proj = U_dtheta(theta_flat, x)
#      93 M_proj = jnp.mean(u_dth_proj[:, :, jnp.newaxis] * u_dth_proj[:, jnp.newaxis, :], axis=0) # {M_proj}_ij = <u_dth_i, u_dth_j>
#      94 u_dth_ort = orthogonalize(u_dth, M_proj)
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/jax/_src/api.py:1240, in vmap.<locals>.vmap_f(*args, **kwargs)
#    1237 in_axes_flat = flatten_axes("vmap in_axes", in_tree, (in_axes, 0), kws=True)
#    1238 axis_size_ = (axis_size if axis_size is not None else
#    1239               _mapped_axis_size(fun, in_tree, args_flat, in_axes_flat, "vmap"))
# -> 1240 out_flat = batching.batch(
#    1241     flat_fun, axis_name, axis_size_, in_axes_flat,
#    1242     lambda: flatten_axes("vmap out_axes", out_tree(), out_axes),
#    1243     spmd_axis_name=spmd_axis_name
#    1244 ).call_wrapped(*args_flat)
#    1245 return tree_unflatten(out_tree(), out_flat)
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/jax/_src/linear_util.py:192, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     189 gen = gen_static_args = out_store = None
#     191 try:
# --> 192   ans = self.f(*args, **dict(self.params, **kwargs))
#     193 except:
#     194   # Some transformations yield from inside context managers, so we have to
#     195   # interrupt them before reraising the exception. Otherwise they will only
#     196   # get garbage-collected at some later time, running their cleanup tasks
#     197   # only after this exception is handled, which can corrupt the global
#     198   # state.
#     199   while stack:
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/jax/_src/api.py:647, in grad.<locals>.grad_f(*args, **kwargs)
#     644 @wraps(fun, docstr=docstr, argnums=argnums)
#     645 @api_boundary
#     646 def grad_f(*args, **kwargs):
# --> 647   _, g = value_and_grad_f(*args, **kwargs)
#     648   return g
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/jax/_src/api.py:717, in value_and_grad.<locals>.value_and_grad_f(*args, **kwargs)
#     715   _check_input_dtype_grad(holomorphic, allow_int, leaf)
#     716 if not has_aux:
# --> 717   ans, vjp_py = _vjp(f_partial, *dyn_args)
#     718 else:
#     719   ans, vjp_py, aux = _vjp(
#     720       f_partial, *dyn_args, has_aux=True)
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/jax/_src/api.py:2205, in _vjp(fun, has_aux, *primals)
#    2203 if not has_aux:
#    2204   flat_fun, out_tree = flatten_fun_nokwargs(fun, in_tree)
# -> 2205   out_primal, out_vjp = ad.vjp(flat_fun, primals_flat)
#    2206   out_tree = out_tree()
#    2207 else:
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/jax/_src/interpreters/ad.py:143, in vjp(traceable, primals, has_aux)
#     141 def vjp(traceable, primals, has_aux=False):
#     142   if not has_aux:
# --> 143     out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     144   else:
#     145     out_primals, pvals, jaxpr, consts, aux = linearize(traceable, *primals, has_aux=True)
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/jax/_src/interpreters/ad.py:132, in linearize(traceable, *primals, **kwargs)
#     130 _, in_tree = tree_flatten(((primals, primals), {}))
#     131 jvpfun_flat, out_tree = flatten_fun(jvpfun, in_tree)
# --> 132 jaxpr, out_pvals, consts = pe.trace_to_jaxpr_nounits(jvpfun_flat, in_pvals)
#     133 out_primals_pvals, out_tangents_pvals = tree_unflatten(out_tree(), out_pvals)
#     134 assert all(out_primal_pval.is_known() for out_primal_pval in out_primals_pvals)
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/jax/_src/profiler.py:335, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     332 @wraps(func)
#     333 def wrapper(*args, **kwargs):
#     334   with TraceAnnotation(name, **decorator_kwargs):
# --> 335     return func(*args, **kwargs)
#     336   return wrapper
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/jax/_src/interpreters/partial_eval.py:774, in trace_to_jaxpr_nounits(fun, pvals, instantiate)
#     772 with core.new_main(JaxprTrace, name_stack=current_name_stack) as main:
#     773   fun = trace_to_subjaxpr_nounits(fun, main, instantiate)
# --> 774   jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#     775   assert not env
#     776   del main, fun, env
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/jax/_src/linear_util.py:192, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     189 gen = gen_static_args = out_store = None
#     191 try:
# --> 192   ans = self.f(*args, **dict(self.params, **kwargs))
#     193 except:
#     194   # Some transformations yield from inside context managers, so we have to
#     195   # interrupt them before reraising the exception. Otherwise they will only
#     196   # get garbage-collected at some later time, running their cleanup tasks
#     197   # only after this exception is handled, which can corrupt the global
#     198   # state.
#     199   while stack:
#
# File /mnt/c/Users/frabe/Desktop/EPFL/2nd-semester/semester-project/Neural_Galerkin/./src/Utils.py:24, in unraveler.<locals>.wrapper(*args, **kwargs)
#      22     args = tuple(args)
#      23 # return f(*args, **kwargs) # evaluate the neural network on the unflattened parameters
# ---> 24 return f(*args, **kwargs).squeeze()
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/flax/linen/module.py:2151, in Module.apply(self, variables, rngs, method, mutable, capture_intermediates, *args, **kwargs)
#    2149   method = self.__call__
#    2150 method = _get_unbound_fn(method)
# -> 2151 return apply(
#    2152   method,
#    2153   self,
#    2154   mutable=mutable,
#    2155   capture_intermediates=capture_intermediates,
#    2156 )(variables, *args, **kwargs, rngs=rngs)
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/flax/core/scope.py:1101, in apply.<locals>.wrapper(variables, rngs, *args, **kwargs)
#    1096   raise errors.ApplyScopeInvalidVariablesStructureError(variables)
#    1098 with bind(
#    1099   variables, rngs=rngs, mutable=mutable, flags=flags
#    1100 ).temporary() as root:
# -> 1101   y = fn(root, *args, **kwargs)
#    1102 if mutable is not False:
#    1103   return y, root.mutable_variables()
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/flax/linen/module.py:2901, in apply.<locals>.scope_fn(scope, *args, **kwargs)
#    2899 _context.capture_stack.append(capture_intermediates)
#    2900 try:
# -> 2901   return fn(module.clone(parent=scope, _deep_clone=True), *args, **kwargs)
#    2902 finally:
#    2903   _context.capture_stack.pop()
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/flax/linen/module.py:694, in wrap_method_once.<locals>.wrapped_module_method(*args, **kwargs)
#     692 if args and isinstance(args[0], Module):
#     693   self, args = args[0], args[1:]
# --> 694   return self._call_wrapped_method(fun, args, kwargs)
#     695 else:
#     696   return fun(*args, **kwargs)
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/flax/linen/module.py:1226, in Module._call_wrapped_method(self, fun, args, kwargs)
#    1224 if _use_named_call:
#    1225   with jax.named_scope(_derive_profiling_name(self, fun)):
# -> 1226     y = run_fun(self, *args, **kwargs)
#    1227 else:
#    1228   y = run_fun(self, *args, **kwargs)
#
# File /mnt/c/Users/frabe/Desktop/EPFL/2nd-semester/semester-project/Neural_Galerkin/./src/NeuralNetwork.py:64, in ShallowNetKdV.__call__(self, x)
#      61 net = nn.Sequential([PeriodicPhiKdV(self.m, self.L),
#      62                      nn.Dense(features=1, use_bias=False)])
#      63 if len(x.shape) == 1:
# ---> 64     return jnp.squeeze(net(x), 0)
#      65 return net(x)
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/flax/linen/module.py:694, in wrap_method_once.<locals>.wrapped_module_method(*args, **kwargs)
#     692 if args and isinstance(args[0], Module):
#     693   self, args = args[0], args[1:]
# --> 694   return self._call_wrapped_method(fun, args, kwargs)
#     695 else:
#     696   return fun(*args, **kwargs)
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/flax/linen/module.py:1226, in Module._call_wrapped_method(self, fun, args, kwargs)
#    1224 if _use_named_call:
#    1225   with jax.named_scope(_derive_profiling_name(self, fun)):
# -> 1226     y = run_fun(self, *args, **kwargs)
#    1227 else:
#    1228   y = run_fun(self, *args, **kwargs)
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/flax/linen/combinators.py:105, in Sequential.__call__(self, *args, **kwargs)
#     102 if not self.layers:
#     103   raise ValueError(f'Empty Sequential module {self.name}.')
# --> 105 outputs = self.layers[0](*args, **kwargs)
#     106 for layer in self.layers[1:]:
#     107   if isinstance(outputs, tuple):
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/flax/linen/module.py:694, in wrap_method_once.<locals>.wrapped_module_method(*args, **kwargs)
#     692 if args and isinstance(args[0], Module):
#     693   self, args = args[0], args[1:]
# --> 694   return self._call_wrapped_method(fun, args, kwargs)
#     695 else:
#     696   return fun(*args, **kwargs)
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/flax/linen/module.py:1226, in Module._call_wrapped_method(self, fun, args, kwargs)
#    1224 if _use_named_call:
#    1225   with jax.named_scope(_derive_profiling_name(self, fun)):
# -> 1226     y = run_fun(self, *args, **kwargs)
#    1227 else:
#    1228   y = run_fun(self, *args, **kwargs)
#
# File /mnt/c/Users/frabe/Desktop/EPFL/2nd-semester/semester-project/Neural_Galerkin/./src/NeuralNetwork.py:29, in PeriodicPhiKdV.__call__(self, x)
#      26     return jnp.exp(- w ** 2 * jnp.linalg.norm(jnp.sin(jnp.pi * jnp.add(jnp.expand_dims(x, 0), - b) / self.L), axis=1) ** 2)
#      28 # Apply phi to each input
# ---> 29 phi = jax.vmap(apply_phi)(x)
#      31 return phi
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/jax/_src/api.py:1240, in vmap.<locals>.vmap_f(*args, **kwargs)
#    1237 in_axes_flat = flatten_axes("vmap in_axes", in_tree, (in_axes, 0), kws=True)
#    1238 axis_size_ = (axis_size if axis_size is not None else
#    1239               _mapped_axis_size(fun, in_tree, args_flat, in_axes_flat, "vmap"))
# -> 1240 out_flat = batching.batch(
#    1241     flat_fun, axis_name, axis_size_, in_axes_flat,
#    1242     lambda: flatten_axes("vmap out_axes", out_tree(), out_axes),
#    1243     spmd_axis_name=spmd_axis_name
#    1244 ).call_wrapped(*args_flat)
#    1245 return tree_unflatten(out_tree(), out_flat)
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/jax/_src/linear_util.py:192, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     189 gen = gen_static_args = out_store = None
#     191 try:
# --> 192   ans = self.f(*args, **dict(self.params, **kwargs))
#     193 except:
#     194   # Some transformations yield from inside context managers, so we have to
#     195   # interrupt them before reraising the exception. Otherwise they will only
#     196   # get garbage-collected at some later time, running their cleanup tasks
#     197   # only after this exception is handled, which can corrupt the global
#     198   # state.
#     199   while stack:
#
# File /mnt/c/Users/frabe/Desktop/EPFL/2nd-semester/semester-project/Neural_Galerkin/./src/NeuralNetwork.py:26, in PeriodicPhiKdV.__call__.<locals>.apply_phi(x)
#      25 def apply_phi(x):
# ---> 26     return jnp.exp(- w ** 2 * jnp.linalg.norm(jnp.sin(jnp.pi * jnp.add(jnp.expand_dims(x, 0), - b) / self.L), axis=1) ** 2)
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/jax/_src/numpy/array_methods.py:735, in _forward_operator_to_aval.<locals>.op(self, *args)
#     734 def _forward_operator_to_aval(name):
# --> 735   def op(self, *args):
#     736     return getattr(self.aval, f"_{name}")(self, *args)
#     737   return op
#
# KeyboardInterrupt:

# %%
solution, timesteps, _ = neural_galerkin(theta=theta, # initial parameters
                                         net=net, # neural network
                                         problem_data=problem_data, # problem data
                                         n=1000, # sample points
                                         rhs=rhs_kdv, # problem RHS
                                         x_init=None,
                                         sampler='uniform',
                                         scheme='rk45'
                                        )

# %%
plot_solution(solution, timesteps, problem_data)

# %%
# plot_animation(solution, timesteps, problem_data)

# %% [markdown]
# ### Compute relative error

# %%
errors = compute_error(solution, timesteps, exactKdVTwoSol, problem_data)

# %%
plot_error(errors, timesteps, 'Relative L2 error for NG')

# %% [markdown]
# ### Comparison with linear fitted Neural Galerkin

# %%
training_data_linear = TrainingData(m=30, # number of neurons per layer
                                    l=1, # number of layers
                                    batch_size=5000, # batch size
                                    epochs=2000, # number of epochs
                                    gamma=0.1, # learning rate
                                    seed=0, # seed for reproducibility
                                    scheduler=optax.exponential_decay(init_value=0.1, transition_steps=1000, decay_rate=0.9) # learning rate scheduler
                                    # scheduler=optax.piecewise_constant_schedule(init_value=0.1, boundaries_and_scales={1000: 0.1}) # learning rate scheduler
                                   )

net_linear = ShallowNetKdV(training_data_linear.m, problem_data.domain[1] - problem_data.domain[0])

# %%
initial_fit = False

if initial_fit:
    theta_linear = init_neural_galerkin(net_linear, problem_data, training_data_linear) # train a NN to fit the initial condition
    jnp.save('./data/theta_init_' + problem_data.name + '_linear_' + str(training_data.seed) + '.npy', theta_linear)
else:
    theta_linear = jnp.load('./data/theta_init_' + problem_data.name + '_linear_' + str(training_data.seed) + '.npy', allow_pickle=True).item()
    x_plot = jnp.linspace(problem_data.domain[0], problem_data.domain[1], problem_data.N)
    relative_error = jnp.linalg.norm(net_linear.apply(theta_linear, x_plot.reshape(-1, 1)) - exactKdVTwoSol(x_plot, 0)) / jnp.linalg.norm(exactKdVTwoSol(x_plot, 0))
    print("Relative error of the initial fit:", relative_error)

# %%
# Redefine the NN to freeze the parameters of the periodic unit

net_linear = ShallowNetKdVLinear(training_data_linear.m, problem_data.domain[1] - problem_data.domain[0], 
                                 theta_linear['params']['PeriodicPhiKdV_0']['kernel'], # weights
                                 theta_linear['params']['PeriodicPhiKdV_0']['bias'] # biases
                                )

theta_linear = {'params': {'Dense_0': theta_linear['params']['Dense_0']}}

# %%
solution_linear, timesteps_linear, _ = neural_galerkin(theta=theta_linear, # initial parameters
                                                       net=net_linear, # neural network
                                                       problem_data=problem_data, # problem data
                                                       n=1000, # sample points
                                                       rhs=rhs_kdv, # problem RHS
                                                       x_init=None,
                                                       sampler='uniform',
                                                       scheme='rk45'
                                                      )

# %%
plot_solution(solution_linear, timesteps_linear, problem_data)

# %%
errors_linear = compute_error(solution_linear, timesteps_linear, exactKdVTwoSol, problem_data)

# %%
plot_error(errors_linear,timesteps_linear, 'Relative L2 error for linear NG')

# %% [markdown]
# ### Comparison with linear equidistant Neural Galerkin

# %%
net_equi = ShallowNetKdVLinear(training_data_linear.m, problem_data.domain[1] - problem_data.domain[0], 
                               12 * jnp.ones(training_data_linear.m), # weights
                               jnp.linspace(problem_data.domain[0], problem_data.domain[1], training_data_linear.m).reshape(-1, 1) # biases
                              )

# %%
initial_fit = False

if initial_fit:
    theta_equi = init_neural_galerkin(net_equi, problem_data, training_data_linear) # train a NN to fit the initial condition
    jnp.save('./data/theta_init_' + problem_data.name + '_equi_' + str(training_data_linear.seed) + '.npy', theta_equi)
else:
    theta_equi = jnp.load('./data/theta_init_' + problem_data.name + '_equi_' + str(training_data_linear.seed) + '.npy', allow_pickle=True).item()
    x_plot = jnp.linspace(problem_data.domain[0], problem_data.domain[1], problem_data.N)
    relative_error = jnp.linalg.norm(net_equi.apply(theta_equi, x_plot.reshape(-1, 1)) - exactKdVTwoSol(x_plot, 0)) / jnp.linalg.norm(exactKdVTwoSol(x_plot, 0))
    print("Relative error of the initial fit:", relative_error)

# %%
solution_equi, timesteps_equi, _ = neural_galerkin(theta=theta_equi, # initial parameters
                                                   net=net_equi, # neural network
                                                   problem_data=problem_data, # problem data
                                                   n=1000, # sample points
                                                   rhs=rhs_kdv, # problem RHS
                                                   x_init=None,
                                                   sampler='uniform',
                                                   scheme='rk45'
                                                  )

# %%
plot_solution(solution_equi, timesteps_equi, problem_data)

# %%
errors_equi = compute_error(solution_equi, timesteps_equi, exactKdVTwoSol, problem_data)

# %%
plot_error(errors_equi, timesteps_equi, 'Relative L2 error for linear equidistant NG')

# %% [markdown]
# ### Comparison with Neural Galerkin with adaptive measure

# %%
# Accept-reject to sample from the initial condition

from scipy.stats import norm, uniform
from numpy import random

def init_samples_kdv(n, max_it=1000, seed=0):

    random.seed(seed) # set seed for reproducibility

    def KdVWrapper(x):
        x = jnp.array([x])
        kdv = exactKdVTwoSol(x, 0)
        return kdv.squeeze()

    g = norm(loc=-5, scale=4.5) # proposal distribution
    C = 29 # scaling constant

    x = []

    for _ in range(n):
        it = 0
        while it < max_it:
            y = g.rvs() # sample from the Gaussian
            u = uniform.rvs() # sample from a uniform in [0, 1]
            if u <= KdVWrapper(y) / (C * g.pdf(y)):
                x.append(y)
                break
            it += 1
        if it >= max_it:
            raise Exception("AR did not converge.")

    return jnp.array(x)

# %%
# x_init = init_samples_kdv(100)
# x_plot = jnp.linspace(problem_data.domain[0], problem_data.domain[1], 1000)
# plt.plot(x_plot, problem_data.initial_fn(x_plot))
# plt.plot(x_init, jnp.zeros(100), '.')
# plt.show()

# %%
solution_adaptive, timesteps_adaptive, _ = neural_galerkin(theta=theta, # initial parameters
                                                           net=net, # neural network
                                                           problem_data=problem_data, # problem data
                                                           n=100, # sample points
                                                           rhs=rhs_kdv, # problem RHS
                                                           x_init=init_samples_kdv(100).reshape(-1, 1), # particles
                                                           sampler='svgd',
                                                           scheme='rk45'
                                                          )
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 solution_adaptive, timesteps_adaptive, _ = neural_galerkin(theta=theta, # initial parameters
#       2                                                            net=net, # neural network
#       3                                                            problem_data=problem_data, # problem data
#       4                                                            n=100, # sample points
#       5                                                            rhs=rhs_kdv, # problem RHS
#       6                                                            x_init=init_samples_kdv(100).reshape(-1, 1), # particles
#       7                                                            sampler='svgd',
#       8                                                            scheme='rk45'
#       9                                                           )
#
# File /mnt/c/Users/frabe/Desktop/EPFL/2nd-semester/semester-project/Neural_Galerkin/./src/Solver.py:265, in neural_galerkin(theta, net, problem_data, n, rhs, x_init, sampler, scheme, diagnostic_on, plot_on)
#     262 start = time.time()
#     264 if scheme == 'rk45':
# --> 265     solution, timesteps, diagnostic = runge_kutta_scheme(theta_flat, problem_data, n, u_fn, rhs, x_init, sampler, diagnostic_on, plot_on)
#     266 elif scheme == 'bwe':
#     267     # solution, timesteps, diagnostic = backward_euler_scheme(theta_flat, problem_data, n, u_fn, rhs, x_init, sampler, diagnostic_on, plot_on)
#     268     raise NotImplementedError('Backward Euler scheme is not implemented yet.')
#
# File /mnt/c/Users/frabe/Desktop/EPFL/2nd-semester/semester-project/Neural_Galerkin/./src/Solver.py:95, in runge_kutta_scheme(theta_flat, problem_data, n, u_fn, rhs, x_init, sampler, diagnostic_on, plot_on)
#      92     diagnostic.min_eig.append(jnp.min(eigs))
#      94 # Integration step
# ---> 95 scheme.step()
#      97 if plot_on and it % 10 == 0:
#      99     plot1 = plt.scatter(x, - 0.1 * jnp.ones(n), color='blue', marker='.')
#
# File ~/miniconda3/envs/jax-env/lib/python3.11/site-packages/scipy/integrate/_ivp/base.py:186, in OdeSolver.step(self)
#     176 """Perform one integration step.
#     177
#     178 Returns
#    (...)
#     183     otherwise.
#     184 """
#     185 if self.status != 'running':
# --> 186     raise RuntimeError("Attempt to step on a failed or finished "
#     187                        "solver.")
#     189 if self.n == 0 or self.t == self.t_bound:
#     190     # Handle corner cases of empty solver or no integration.
#     191     self.t_old = self.t
#
# RuntimeError: Attempt to step on a failed or finished solver.

# %%
plot_solution(solution_adaptive, timesteps_adaptive, problem_data)

# %%
errors_adaptive = compute_error(solution_adaptive, timesteps_adaptive, exactKdVTwoSol, problem_data)

# %%
plot_error(errors_adaptive, timesteps_adaptive, 'Relative L2 error for NG with adaptive sampling')

# %% [markdown]
# ### Final error plot

# %%
errors_list = [errors, errors_linear, errors_equi, errors_adaptive]
timesteps_list = [timesteps, timesteps_linear, timesteps_equi, timesteps_adaptive]
names_list = ['NG', 'linear NG', 'equidistant NG', 'adaptive NG']
plot_error_comparison(errors_list, timesteps_list, names_list)
